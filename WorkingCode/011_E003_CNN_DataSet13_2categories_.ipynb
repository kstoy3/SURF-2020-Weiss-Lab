# %% [markdown]
# CNN LSTM
#
# Data Set 14
# Using data zero data zero padding

# %%
# %load_ext tensorboard
import tensorflow as tf
import datetime
import keras

import numpy as np
import pandas as pd
from keras.models import Sequential, Model, load_model
from keras.layers import Input ,Dense, Dropout, Activation, LSTM, Conv1D
from keras.layers import Lambda, Convolution1D, MaxPooling1D, Flatten, Reshape, BatchNormalization
from keras.layers.wrappers import TimeDistributed
from keras.layers.pooling import GlobalAveragePooling1D
from keras.optimizers import SGD, Adam
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from keras.metrics import categorical_crossentropy, binary_crossentropy

#from spp.SpatialPyramidPooling import SpatialPyramidPooling

#For data saving
import pickle
import random
#other imports
import gzip
import glob
import os
import keras.backend as K
import os
import time 
#cwd = os.path.dirname(os.path.realpath("SURF_001_TwoClass13.ipynb"))

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# !rm -rf ./logs/

# %%
genome = ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']

# %% [markdown]
# **Creating Dataframe**
#
# https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly

# %%
import keras

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, batch_size=32, dim=(1000, 4), n_channels=0,
                 n_classes=2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, 1000, 4))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            X[i,] = np.load('../model_11_data_4/' + ID + '.npy')

            # Store class
            y[i] = self.labels[ID]

        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)

# %%
dense_layer = 1
layer_size = 64 
conv_layer = 2
seq_length = 1000
base_pair = 4
num_strides = 1
pool_size = 4

# %%
test_count = 0
with open('../partition_train_val_a.dat', 'rb') as f:
    partition = pickle.load(f)
for index in partition['train']:
    a = partition['labels'][index][0][0]
    if test_count < 10:
        print(a)
    partition['labels'][index] = a
    test_count += 1
    if test_count < 10:
        print(partition['labels'][index])
for index in partition['validation']:
    a = partition['labels'][index][0][0]
    partition['labels'][index] = a
    test_count += 1
    if test_count < 20:
        print(partition['labels'][index])

# %%
cat_1 = 0
cat_0 = 0
for i in partition['train']:
    if partition['labels'][i] == 0:
        cat_0 += 1
    elif partition['labels'][i] == 1:
        cat_1 += 1
    else:
        print('issue')

# %%
print(cat_1)
print(cat_0)

# %%
# Parameters
params = {'dim': (32,1000,4),
          'batch_size': 64,
          'n_classes': 2,
          'n_channels': 1,
          'shuffle': True}

# Datasets
#with open('../partition_train_val_a.dat', 'rb') as f:
   # partition = pickle.load(f)

labels = partition['labels']

# Generators
training_generator = DataGenerator(partition['train'], labels, **params)
validation_generator = DataGenerator(partition['validation'], labels, **params)

# Design model
model = Sequential()
model.add(Conv1D(filters=layer_size, kernel_size=(4), input_shape=(seq_length, 4), activation='relu', strides=1, padding='valid'))
model.add(Conv1D(layer_size, 4, batch_input_shape=(32, seq_length, 4), strides=1, padding='valid', activation='relu'))
model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))
model.add(Dropout(0.1, noise_shape=None, seed=None))

model.add(Flatten())

model.add(Dense(12))
model.add(Activation('relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())

# Train model on dataset
model.fit_generator(generator=training_generator,
                    validation_data=validation_generator,
                    use_multiprocessing=False)

# %%
with open('../partition_train_val_a.dat', 'rb') as f:
    partition = pickle.load(f)
train_samples = partition['train']
val_samples = partition['validation']
random.shuffle(train_samples)
random.shuffle(val_samples)

labels = partition['labels']
partition['train'] = train_samples
partition['validation'] = val_samples

print(len(train_samples))
for ID in train_samples:
    if labels[ID][0][0] == 0:
        train_samples.remove(ID)
print(len(train_samples))
print(labels[train_samples[0]])

print(len(val_samples))
for ID in val_samples:
    if labels[ID][0][0] == 0:
        val_samples.remove(ID)
print(len(val_samples))
print(labels[val_samples[0]])


'''
a = partition['train'][0]
print(a)
print(partition['labels'][a] )
train_labels = np.empty(1, dtype=np.int8)
train_samples = []
train_labels[0] = partition['labels'][a] 
train_samples = np.load('../model_11_data_4/' + partition['train'][0] + '.npy')


print(train_labels.shape)
print(train_samples.shape)


val_labels = train_labels
val_samples = train_samples
print(val_labels.shape)
print(val_samples.shape)
'''



# Parameters
params = {'dim': (32,1000,4),
          'batch_size': 64,
          'n_classes': 2,
          'n_channels': 1,
          'shuffle': True}

# Datasets
#with open('../partition_train_val_a.dat', 'rb') as f:
   # partition = pickle.load(f)


# Generators
#training_generator = DataGenerator(partition['train'], labels, **params)
#validation_generator = DataGenerator(partition['validation'], labels, **params)

dense_layers = [1]
layer_sizes = [64]
conv_layers = [1]

# Design model
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            Earlystop = EarlyStopping(
            monitor='val_loss', min_delta=0, patience=25, verbose=0, mode='auto',
            baseline=None, restore_best_weights=True)
            count_input_train = 0
            count_input_validation = 0
            while count_input_train < len(partition['train']):
                Y_train = np.zeros((200, 2), dtype=np.int8)
                X_train = np.zeros((200, 1000, 4), dtype=np.int8)
                Y_val = np.zeros((40, 2), dtype=np.int8)
                X_val = np.zeros((40, 1000, 4), dtype=np.int8)
                if count_input_train < (len(train_samples) - 200):
                    for i in range(0, 200):
                        a = train_samples[count_input_train]
                        X_train[i, :, :] = np.load('../model_11_data_4/' + train_samples[count_input_train] + '.npy') 
                        Y_train[i, :] = partition['labels'][a] 
                        count_input_train += 1
                else:
                    count_input_train += 1000
                if count_input_validation < (len(partition['validation']) - 40):
                    for i in range(0, 40):
                        a = partition['validation'][count_input_validation]
                        X_val[i, :, :] = np.load('../model_11_data_4/' + partition['validation'][count_input_validation] + '.npy') 
                        Y_val[i, :] = partition['labels'][a] 
                        count_input_validation += 1

                model = Sequential()
                model.add(Conv1D(filters=layer_size, kernel_size=(4), input_shape=(seq_length, 4), activation='relu', strides=1, padding='valid'))
                model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))
                model.add(Conv1D(layer_size, 4, batch_input_shape=(1, seq_length, 4), strides=1, padding='valid', activation='relu'))
                model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))

                model.add(Dropout(0.01, noise_shape=None, seed=None))
                model.add(Conv1D(layer_size, 4, batch_input_shape=(1, seq_length, 4), strides=1, padding='valid', activation='relu'))
                model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))

                model.add(Dropout(0.01, noise_shape=None, seed=None))
                model.add(Conv1D(layer_size, 4, batch_input_shape=(1, seq_length, 4), strides=1, padding='valid', activation='relu'))
                model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))

                model.add(Dropout(0.01, noise_shape=None, seed=None))

                for l in range(conv_layer-1):
                    model.add(MaxPooling1D(pool_size=4, strides=None, padding='valid', data_format='channels_last'))
                    model.add(Conv1D(layer_size, 4, activation='relu'))

                #model.add(MaxPooling1D(pool_size=2, strides=None, padding='valid', data_format='channels_last'))
                #model.add(Conv1D(64, 4, activation='relu'))

                model.add(Dropout(0.1, noise_shape=None, seed=None))

                model.add(LSTM(128))

                model.add(Flatten())
                
                model.add(Dense(512))
                model.add(Activation("relu"))
                model.add(Dropout(0.01))
                model.add(Dense(512))
                model.add(Activation("relu"))
                model.add(Dropout(0.01))

                for l in range(dense_layer):
                    model.add(Dense(128))
                    model.add(Activation('relu'))
                model.add(Dense(2, activation='softmax'))
                
                opt = keras.optimizers.Adam(learning_rate=0.001)


               # optimizer = keras.optimizers.Adam(lr=0.00001)
                model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
                if count_input_train < 400:
                    print(model.summary())
                    model.save('../Models_H5/011_{}-conv-{}-nodes-{}-dense-{}CNNLSTM'.format(conv_layer, layer_size, dense_layer, int(time.time())))
                                # Train model on dataset
                model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=500, callbacks=[Earlystop], verbose=2)
# Out:
# 54082
# 35323
# [[1 0]]
# 13520
# 8811
# [[1 0]]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 997, 64)           1088
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 249, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 246, 64)           16448
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 61, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 61, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 58, 64)            16448
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 14, 64)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 11, 64)            16448
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 2, 64)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 64)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 64)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               98816
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 543,874
# Trainable params: 543,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\kriss\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\kriss\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../Models_H5/011_1-conv-64-nodes-1-dense-1601503002CNNLSTM\assets
# Epoch 1/500
# 7/7 - 2s - loss: 0.6120 - accuracy: 0.7250 - val_loss: 0.5287 - val_accuracy: 0.7500
# Epoch 2/500
# 7/7 - 0s - loss: 0.5629 - accuracy: 0.7250 - val_loss: 0.5685 - val_accuracy: 0.7500
# Epoch 3/500
# 7/7 - 0s - loss: 0.5564 - accuracy: 0.7250 - val_loss: 0.5154 - val_accuracy: 0.7500
# Epoch 4/500
# 7/7 - 0s - loss: 0.5500 - accuracy: 0.7250 - val_loss: 0.5133 - val_accuracy: 0.7500
# Epoch 5/500
# 7/7 - 0s - loss: 0.5332 - accuracy: 0.7250 - val_loss: 0.5018 - val_accuracy: 0.7500
# Epoch 6/500
# 7/7 - 0s - loss: 0.5395 - accuracy: 0.7250 - val_loss: 0.5111 - val_accuracy: 0.7500
# Epoch 7/500
# 7/7 - 0s - loss: 0.5465 - accuracy: 0.7250 - val_loss: 0.4911 - val_accuracy: 0.7500
# Epoch 8/500
# 7/7 - 0s - loss: 0.5247 - accuracy: 0.7250 - val_loss: 0.4980 - val_accuracy: 0.8000
# Epoch 9/500
# 7/7 - 0s - loss: 0.5505 - accuracy: 0.7750 - val_loss: 0.5049 - val_accuracy: 0.8000
# Epoch 10/500
# 7/7 - 0s - loss: 0.5141 - accuracy: 0.7650 - val_loss: 0.4821 - val_accuracy: 0.8000
# Epoch 11/500
# 7/7 - 0s - loss: 0.4990 - accuracy: 0.7850 - val_loss: 0.5054 - val_accuracy: 0.8000
# Epoch 12/500
# 7/7 - 0s - loss: 0.5213 - accuracy: 0.7750 - val_loss: 0.4730 - val_accuracy: 0.8000
# Epoch 13/500
# 7/7 - 0s - loss: 0.4996 - accuracy: 0.7750 - val_loss: 0.4706 - val_accuracy: 0.8000
# Epoch 14/500
# 7/7 - 0s - loss: 0.4777 - accuracy: 0.7800 - val_loss: 0.4865 - val_accuracy: 0.8250
# Epoch 15/500
# 7/7 - 0s - loss: 0.4741 - accuracy: 0.7800 - val_loss: 0.4693 - val_accuracy: 0.8250
# Epoch 16/500
# 7/7 - 0s - loss: 0.4722 - accuracy: 0.8000 - val_loss: 0.4661 - val_accuracy: 0.8250
# Epoch 17/500
# 7/7 - 0s - loss: 0.4427 - accuracy: 0.8100 - val_loss: 0.4592 - val_accuracy: 0.8250
# Epoch 18/500
# 7/7 - 0s - loss: 0.4163 - accuracy: 0.8200 - val_loss: 0.5632 - val_accuracy: 0.7250
# Epoch 19/500
# 7/7 - 0s - loss: 0.4294 - accuracy: 0.8300 - val_loss: 0.7063 - val_accuracy: 0.5000
# Epoch 20/500
# 7/7 - 0s - loss: 0.4091 - accuracy: 0.8000 - val_loss: 0.4775 - val_accuracy: 0.8250
# Epoch 21/500
# 7/7 - 0s - loss: 0.3646 - accuracy: 0.8450 - val_loss: 0.5173 - val_accuracy: 0.7500
# Epoch 22/500
# 7/7 - 0s - loss: 0.3779 - accuracy: 0.8100 - val_loss: 0.4652 - val_accuracy: 0.8250
# Epoch 23/500
# 7/7 - 0s - loss: 0.2972 - accuracy: 0.8700 - val_loss: 0.5297 - val_accuracy: 0.8250
# Epoch 24/500
# 7/7 - 0s - loss: 0.2689 - accuracy: 0.8950 - val_loss: 0.5542 - val_accuracy: 0.7500
# Epoch 25/500
# 7/7 - 0s - loss: 0.2230 - accuracy: 0.9050 - val_loss: 0.5760 - val_accuracy: 0.8000
# Epoch 26/500
# 7/7 - 0s - loss: 0.2450 - accuracy: 0.8750 - val_loss: 0.5010 - val_accuracy: 0.8000
# Epoch 27/500
# 7/7 - 0s - loss: 0.1580 - accuracy: 0.9300 - val_loss: 0.5187 - val_accuracy: 0.8000
# Epoch 28/500
# 7/7 - 0s - loss: 0.1174 - accuracy: 0.9500 - val_loss: 0.9241 - val_accuracy: 0.8000
# Epoch 29/500
# 7/7 - 0s - loss: 0.1432 - accuracy: 0.9450 - val_loss: 0.8176 - val_accuracy: 0.8750
# Epoch 30/500
# 7/7 - 0s - loss: 0.1129 - accuracy: 0.9550 - val_loss: 0.6443 - val_accuracy: 0.7250
# Epoch 31/500
# 7/7 - 0s - loss: 0.0514 - accuracy: 0.9900 - val_loss: 1.1209 - val_accuracy: 0.6000
# Epoch 32/500
# 7/7 - 0s - loss: 0.2422 - accuracy: 0.9250 - val_loss: 0.8392 - val_accuracy: 0.5750
# Epoch 33/500
# 7/7 - 0s - loss: 0.0484 - accuracy: 0.9800 - val_loss: 1.3055 - val_accuracy: 0.4750
# Epoch 34/500
# 7/7 - 0s - loss: 0.1249 - accuracy: 0.9400 - val_loss: 0.7869 - val_accuracy: 0.8250
# Epoch 35/500
# 7/7 - 0s - loss: 0.1031 - accuracy: 0.9600 - val_loss: 0.7876 - val_accuracy: 0.6250
# Epoch 36/500
# 7/7 - 0s - loss: 0.0694 - accuracy: 0.9800 - val_loss: 0.5744 - val_accuracy: 0.8000
# Epoch 37/500
# 7/7 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.7550 - val_accuracy: 0.7250
# Epoch 38/500
# 7/7 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.7719 - val_accuracy: 0.8000
# Epoch 39/500
# 7/7 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8146 - val_accuracy: 0.8000
# Epoch 40/500
# 7/7 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8178 - val_accuracy: 0.7250
# Epoch 41/500
# 7/7 - 0s - loss: 7.6831e-04 - accuracy: 1.0000 - val_loss: 0.8181 - val_accuracy: 0.7750
# Epoch 42/500
# 7/7 - 0s - loss: 4.3083e-04 - accuracy: 1.0000 - val_loss: 0.8627 - val_accuracy: 0.7750
# Epoch 1/500
# 7/7 - 2s - loss: 0.6617 - accuracy: 0.7000 - val_loss: 0.5935 - val_accuracy: 0.7000
# Epoch 2/500
# 7/7 - 0s - loss: 0.6175 - accuracy: 0.7000 - val_loss: 0.6046 - val_accuracy: 0.7000
# Epoch 3/500
# 7/7 - 0s - loss: 0.5824 - accuracy: 0.7000 - val_loss: 0.6051 - val_accuracy: 0.7000
# Epoch 4/500
# 7/7 - 0s - loss: 0.5818 - accuracy: 0.7000 - val_loss: 0.5889 - val_accuracy: 0.7000
# Epoch 5/500
# 7/7 - 0s - loss: 0.5975 - accuracy: 0.7000 - val_loss: 0.5934 - val_accuracy: 0.7000
# Epoch 6/500
# 7/7 - 0s - loss: 0.5914 - accuracy: 0.7000 - val_loss: 0.5829 - val_accuracy: 0.7000
# Epoch 7/500
# 7/7 - 0s - loss: 0.5718 - accuracy: 0.7000 - val_loss: 0.5825 - val_accuracy: 0.7000
# Epoch 8/500
# 7/7 - 0s - loss: 0.5626 - accuracy: 0.7000 - val_loss: 0.5923 - val_accuracy: 0.7000
# Epoch 9/500
# 7/7 - 0s - loss: 0.5735 - accuracy: 0.7000 - val_loss: 0.5860 - val_accuracy: 0.7000
# Epoch 10/500
# 7/7 - 0s - loss: 0.5665 - accuracy: 0.7000 - val_loss: 0.5668 - val_accuracy: 0.7000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5661 - accuracy: 0.7100 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 12/500
# 7/7 - 0s - loss: 0.5721 - accuracy: 0.7250 - val_loss: 0.5729 - val_accuracy: 0.7500
# Epoch 13/500
# 7/7 - 0s - loss: 0.6003 - accuracy: 0.7600 - val_loss: 0.6117 - val_accuracy: 0.7500
# Epoch 14/500
# 7/7 - 0s - loss: 0.5876 - accuracy: 0.7100 - val_loss: 0.5689 - val_accuracy: 0.7000
# Epoch 15/500
# 7/7 - 0s - loss: 0.5559 - accuracy: 0.7350 - val_loss: 0.5633 - val_accuracy: 0.7500
# Epoch 16/500
# 7/7 - 0s - loss: 0.5708 - accuracy: 0.7350 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 17/500
# 7/7 - 0s - loss: 0.5422 - accuracy: 0.7450 - val_loss: 0.5547 - val_accuracy: 0.7500
# Epoch 18/500
# 7/7 - 0s - loss: 0.5079 - accuracy: 0.7600 - val_loss: 0.5615 - val_accuracy: 0.7500
# Epoch 19/500
# 7/7 - 0s - loss: 0.4637 - accuracy: 0.7850 - val_loss: 0.5774 - val_accuracy: 0.7500
# Epoch 20/500
# 7/7 - 0s - loss: 0.4731 - accuracy: 0.7700 - val_loss: 0.5656 - val_accuracy: 0.7000
# Epoch 21/500
# 7/7 - 0s - loss: 0.3776 - accuracy: 0.8450 - val_loss: 0.5766 - val_accuracy: 0.7500
# Epoch 22/500
# 7/7 - 0s - loss: 0.3668 - accuracy: 0.8400 - val_loss: 0.5394 - val_accuracy: 0.7000
# Epoch 23/500
# 7/7 - 1s - loss: 0.3484 - accuracy: 0.8500 - val_loss: 0.5413 - val_accuracy: 0.7250
# Epoch 24/500
# 7/7 - 0s - loss: 0.3020 - accuracy: 0.8750 - val_loss: 0.6629 - val_accuracy: 0.7500
# Epoch 25/500
# 7/7 - 0s - loss: 0.2532 - accuracy: 0.8850 - val_loss: 0.8011 - val_accuracy: 0.4750
# Epoch 26/500
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8450 - val_loss: 0.5681 - val_accuracy: 0.7000
# Epoch 27/500
# 7/7 - 0s - loss: 0.2629 - accuracy: 0.8900 - val_loss: 0.7567 - val_accuracy: 0.5250
# Epoch 28/500
# 7/7 - 0s - loss: 0.2640 - accuracy: 0.8850 - val_loss: 0.7302 - val_accuracy: 0.7250
# Epoch 29/500
# 7/7 - 0s - loss: 0.2026 - accuracy: 0.9250 - val_loss: 1.0962 - val_accuracy: 0.7500
# Epoch 30/500
# 7/7 - 0s - loss: 0.1979 - accuracy: 0.9100 - val_loss: 0.8409 - val_accuracy: 0.7500
# Epoch 31/500
# 7/7 - 0s - loss: 0.1927 - accuracy: 0.9300 - val_loss: 0.8629 - val_accuracy: 0.5750
# Epoch 32/500
# 7/7 - 0s - loss: 0.2156 - accuracy: 0.8950 - val_loss: 0.7549 - val_accuracy: 0.7000
# Epoch 33/500
# 7/7 - 0s - loss: 0.1789 - accuracy: 0.9200 - val_loss: 1.3000 - val_accuracy: 0.7250
# Epoch 34/500
# 7/7 - 0s - loss: 0.1675 - accuracy: 0.9300 - val_loss: 0.7765 - val_accuracy: 0.7250
# Epoch 35/500
# 7/7 - 0s - loss: 0.1278 - accuracy: 0.9500 - val_loss: 1.0430 - val_accuracy: 0.7250
# Epoch 36/500
# 7/7 - 0s - loss: 0.0828 - accuracy: 0.9650 - val_loss: 1.9573 - val_accuracy: 0.7250
# Epoch 37/500
# 7/7 - 0s - loss: 0.0820 - accuracy: 0.9600 - val_loss: 1.5113 - val_accuracy: 0.7000
# Epoch 38/500
# 7/7 - 0s - loss: 0.0498 - accuracy: 0.9900 - val_loss: 1.8818 - val_accuracy: 0.5750
# Epoch 39/500
# 7/7 - 0s - loss: 0.1165 - accuracy: 0.9550 - val_loss: 1.4626 - val_accuracy: 0.7500
# Epoch 40/500
# 7/7 - 0s - loss: 0.0537 - accuracy: 0.9800 - val_loss: 1.5828 - val_accuracy: 0.7500
# Epoch 41/500
# 7/7 - 0s - loss: 0.0731 - accuracy: 0.9750 - val_loss: 1.3302 - val_accuracy: 0.7500
# Epoch 42/500
# 7/7 - 0s - loss: 0.1407 - accuracy: 0.9550 - val_loss: 1.1424 - val_accuracy: 0.7500
# Epoch 43/500
# 7/7 - 0s - loss: 0.0683 - accuracy: 0.9650 - val_loss: 1.0801 - val_accuracy: 0.7250
# Epoch 44/500
# 7/7 - 0s - loss: 0.0737 - accuracy: 0.9750 - val_loss: 1.6851 - val_accuracy: 0.7250
# Epoch 45/500
# 7/7 - 0s - loss: 0.0953 - accuracy: 0.9550 - val_loss: 1.1155 - val_accuracy: 0.7500
# Epoch 46/500
# 7/7 - 0s - loss: 0.0651 - accuracy: 0.9800 - val_loss: 0.9711 - val_accuracy: 0.7000
# Epoch 47/500
# 7/7 - 0s - loss: 0.0657 - accuracy: 0.9700 - val_loss: 0.9097 - val_accuracy: 0.7750
# Epoch 1/500
# 7/7 - 2s - loss: 0.6583 - accuracy: 0.6650 - val_loss: 0.5516 - val_accuracy: 0.7000
# Epoch 2/500
# 7/7 - 0s - loss: 0.5717 - accuracy: 0.7250 - val_loss: 0.6042 - val_accuracy: 0.7000
# Epoch 3/500
# 7/7 - 0s - loss: 0.5877 - accuracy: 0.7250 - val_loss: 0.5525 - val_accuracy: 0.7000
# Epoch 4/500
# 7/7 - 0s - loss: 0.5717 - accuracy: 0.7250 - val_loss: 0.5540 - val_accuracy: 0.7000
# Epoch 5/500
# 7/7 - 0s - loss: 0.5638 - accuracy: 0.7250 - val_loss: 0.5533 - val_accuracy: 0.7000
# Epoch 6/500
# 7/7 - 0s - loss: 0.5535 - accuracy: 0.7250 - val_loss: 0.5479 - val_accuracy: 0.7000
# Epoch 7/500
# 7/7 - 0s - loss: 0.5569 - accuracy: 0.7250 - val_loss: 0.5422 - val_accuracy: 0.7000
# Epoch 8/500
# 7/7 - 0s - loss: 0.5467 - accuracy: 0.7250 - val_loss: 0.5365 - val_accuracy: 0.7000
# Epoch 9/500
# 7/7 - 0s - loss: 0.5432 - accuracy: 0.7250 - val_loss: 0.5298 - val_accuracy: 0.7000
# Epoch 10/500
# 7/7 - 0s - loss: 0.5229 - accuracy: 0.7250 - val_loss: 0.5114 - val_accuracy: 0.7000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5184 - accuracy: 0.7250 - val_loss: 0.5054 - val_accuracy: 0.7500
# Epoch 12/500
# 7/7 - 0s - loss: 0.5032 - accuracy: 0.7650 - val_loss: 0.5006 - val_accuracy: 0.8000
# Epoch 13/500
# 7/7 - 0s - loss: 0.4978 - accuracy: 0.7550 - val_loss: 0.5143 - val_accuracy: 0.8000
# Epoch 14/500
# 7/7 - 0s - loss: 0.5066 - accuracy: 0.7800 - val_loss: 0.5735 - val_accuracy: 0.8000
# Epoch 15/500
# 7/7 - 0s - loss: 0.5674 - accuracy: 0.7550 - val_loss: 0.5468 - val_accuracy: 0.7250
# Epoch 16/500
# 7/7 - 0s - loss: 0.4890 - accuracy: 0.7500 - val_loss: 0.5450 - val_accuracy: 0.7250
# Epoch 17/500
# 7/7 - 0s - loss: 0.4484 - accuracy: 0.8100 - val_loss: 0.5119 - val_accuracy: 0.8000
# Epoch 18/500
# 7/7 - 0s - loss: 0.4686 - accuracy: 0.8000 - val_loss: 0.5327 - val_accuracy: 0.8000
# Epoch 19/500
# 7/7 - 0s - loss: 0.4781 - accuracy: 0.7900 - val_loss: 0.5268 - val_accuracy: 0.8000
# Epoch 20/500
# 7/7 - 0s - loss: 0.4955 - accuracy: 0.8200 - val_loss: 0.4939 - val_accuracy: 0.7750
# Epoch 21/500
# 7/7 - 0s - loss: 0.4542 - accuracy: 0.7700 - val_loss: 0.5157 - val_accuracy: 0.8000
# Epoch 22/500
# 7/7 - 0s - loss: 0.3573 - accuracy: 0.8750 - val_loss: 0.5632 - val_accuracy: 0.8000
# Epoch 23/500
# 7/7 - 0s - loss: 0.2996 - accuracy: 0.8800 - val_loss: 0.5986 - val_accuracy: 0.8000
# Epoch 24/500
# 7/7 - 0s - loss: 0.2644 - accuracy: 0.8850 - val_loss: 0.8956 - val_accuracy: 0.6250
# Epoch 25/500
# 7/7 - 0s - loss: 0.2428 - accuracy: 0.8950 - val_loss: 0.6926 - val_accuracy: 0.8000
# Epoch 26/500
# 7/7 - 0s - loss: 0.1256 - accuracy: 0.9550 - val_loss: 1.2629 - val_accuracy: 0.6500
# Epoch 27/500
# 7/7 - 0s - loss: 0.1732 - accuracy: 0.9300 - val_loss: 1.2328 - val_accuracy: 0.6250
# Epoch 28/500
# 7/7 - 0s - loss: 0.1512 - accuracy: 0.9450 - val_loss: 1.0042 - val_accuracy: 0.7500
# Epoch 29/500
# 7/7 - 0s - loss: 0.1821 - accuracy: 0.9350 - val_loss: 1.3238 - val_accuracy: 0.7250
# Epoch 30/500
# 7/7 - 0s - loss: 0.1788 - accuracy: 0.9350 - val_loss: 1.0606 - val_accuracy: 0.6500
# Epoch 31/500
# 7/7 - 0s - loss: 0.1965 - accuracy: 0.9400 - val_loss: 0.7541 - val_accuracy: 0.7500
# Epoch 32/500
# 7/7 - 0s - loss: 0.1742 - accuracy: 0.9400 - val_loss: 0.7326 - val_accuracy: 0.7750
# Epoch 33/500
# 7/7 - 0s - loss: 0.1385 - accuracy: 0.9550 - val_loss: 1.6549 - val_accuracy: 0.4250
# Epoch 34/500
# 7/7 - 0s - loss: 0.2693 - accuracy: 0.8700 - val_loss: 1.0311 - val_accuracy: 0.7250
# Epoch 35/500
# 7/7 - 0s - loss: 0.1039 - accuracy: 0.9600 - val_loss: 1.0413 - val_accuracy: 0.7000
# Epoch 36/500
# 7/7 - 0s - loss: 0.0848 - accuracy: 0.9700 - val_loss: 1.2961 - val_accuracy: 0.7250
# Epoch 37/500
# 7/7 - 0s - loss: 0.0550 - accuracy: 0.9800 - val_loss: 1.3203 - val_accuracy: 0.7000
# Epoch 38/500
# 7/7 - 0s - loss: 0.0774 - accuracy: 0.9750 - val_loss: 1.3389 - val_accuracy: 0.7500
# Epoch 39/500
# 7/7 - 0s - loss: 0.0520 - accuracy: 0.9850 - val_loss: 1.4040 - val_accuracy: 0.7000
# Epoch 40/500
# 7/7 - 0s - loss: 0.0283 - accuracy: 0.9900 - val_loss: 1.4431 - val_accuracy: 0.7250
# Epoch 41/500
# 7/7 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.5983 - val_accuracy: 0.7250
# Epoch 42/500
# 7/7 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7837 - val_accuracy: 0.7250
# Epoch 43/500
# 7/7 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.9133 - val_accuracy: 0.7500
# Epoch 44/500
# 7/7 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.3139 - val_accuracy: 0.6500
# Epoch 45/500
# 7/7 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 2.3883 - val_accuracy: 0.6750
# Epoch 1/500
# 7/7 - 2s - loss: 0.5683 - accuracy: 0.7750 - val_loss: 0.6323 - val_accuracy: 0.7000
# Epoch 2/500
# 7/7 - 0s - loss: 0.5422 - accuracy: 0.7750 - val_loss: 0.5965 - val_accuracy: 0.7000
# Epoch 3/500
# 7/7 - 0s - loss: 0.5211 - accuracy: 0.7750 - val_loss: 0.5906 - val_accuracy: 0.7000
# Epoch 4/500
# 7/7 - 0s - loss: 0.4651 - accuracy: 0.7750 - val_loss: 0.6154 - val_accuracy: 0.7000
# Epoch 5/500
# 7/7 - 0s - loss: 0.4568 - accuracy: 0.7750 - val_loss: 0.5650 - val_accuracy: 0.7000
# Epoch 6/500
# 7/7 - 0s - loss: 0.4586 - accuracy: 0.7750 - val_loss: 0.5810 - val_accuracy: 0.7000
# Epoch 7/500
# 7/7 - 0s - loss: 0.4653 - accuracy: 0.7750 - val_loss: 0.5667 - val_accuracy: 0.7000
# Epoch 8/500
# 7/7 - 0s - loss: 0.4594 - accuracy: 0.7750 - val_loss: 0.5566 - val_accuracy: 0.7000
# Epoch 9/500
# 7/7 - 0s - loss: 0.4513 - accuracy: 0.7750 - val_loss: 0.5797 - val_accuracy: 0.7000
# Epoch 10/500
# 7/7 - 0s - loss: 0.4360 - accuracy: 0.7750 - val_loss: 0.5460 - val_accuracy: 0.7000
# Epoch 11/500
# 7/7 - 0s - loss: 0.4414 - accuracy: 0.8000 - val_loss: 0.5735 - val_accuracy: 0.8000
# Epoch 12/500
# 7/7 - 0s - loss: 0.4320 - accuracy: 0.8100 - val_loss: 0.5748 - val_accuracy: 0.8000
# Epoch 13/500
# 7/7 - 0s - loss: 0.4353 - accuracy: 0.8050 - val_loss: 0.5683 - val_accuracy: 0.8000
# Epoch 14/500
# 7/7 - 0s - loss: 0.4264 - accuracy: 0.8050 - val_loss: 0.5652 - val_accuracy: 0.8000
# Epoch 15/500
# 7/7 - 0s - loss: 0.4186 - accuracy: 0.8400 - val_loss: 0.5758 - val_accuracy: 0.7250
# Epoch 16/500
# 7/7 - 0s - loss: 0.4113 - accuracy: 0.8300 - val_loss: 0.5472 - val_accuracy: 0.8000
# Epoch 17/500
# 7/7 - 0s - loss: 0.4149 - accuracy: 0.8100 - val_loss: 0.5902 - val_accuracy: 0.8000
# Epoch 18/500
# 7/7 - 0s - loss: 0.3934 - accuracy: 0.8500 - val_loss: 0.5089 - val_accuracy: 0.8000
# Epoch 19/500
# 7/7 - 0s - loss: 0.4041 - accuracy: 0.8150 - val_loss: 0.7327 - val_accuracy: 0.7000
# Epoch 20/500
# 7/7 - 0s - loss: 0.4200 - accuracy: 0.8200 - val_loss: 0.5247 - val_accuracy: 0.8000
# Epoch 21/500
# 7/7 - 0s - loss: 0.3372 - accuracy: 0.8650 - val_loss: 0.5624 - val_accuracy: 0.8000
# Epoch 22/500
# 7/7 - 0s - loss: 0.2672 - accuracy: 0.9300 - val_loss: 0.4864 - val_accuracy: 0.8500
# Epoch 23/500
# 7/7 - 0s - loss: 0.4698 - accuracy: 0.8100 - val_loss: 1.8901 - val_accuracy: 0.7000
# Epoch 24/500
# 7/7 - 0s - loss: 0.6664 - accuracy: 0.7750 - val_loss: 0.5675 - val_accuracy: 0.7000
# Epoch 25/500
# 7/7 - 0s - loss: 0.5366 - accuracy: 0.8550 - val_loss: 0.5598 - val_accuracy: 0.8000
# Epoch 26/500
# 7/7 - 0s - loss: 0.4411 - accuracy: 0.8500 - val_loss: 0.5884 - val_accuracy: 0.8250
# Epoch 27/500
# 7/7 - 0s - loss: 0.4063 - accuracy: 0.8550 - val_loss: 0.5723 - val_accuracy: 0.8250
# Epoch 28/500
# 7/7 - 0s - loss: 0.3523 - accuracy: 0.8850 - val_loss: 0.4966 - val_accuracy: 0.8250
# Epoch 29/500
# 7/7 - 0s - loss: 0.3438 - accuracy: 0.8700 - val_loss: 0.5855 - val_accuracy: 0.7250
# Epoch 30/500
# 7/7 - 0s - loss: 0.3323 - accuracy: 0.8900 - val_loss: 0.4904 - val_accuracy: 0.8000
# Epoch 31/500
# 7/7 - 0s - loss: 0.3371 - accuracy: 0.8750 - val_loss: 0.6114 - val_accuracy: 0.7250
# Epoch 32/500
# 7/7 - 0s - loss: 0.3531 - accuracy: 0.8500 - val_loss: 0.4850 - val_accuracy: 0.8250
# Epoch 33/500
# 7/7 - 0s - loss: 0.3093 - accuracy: 0.8900 - val_loss: 0.5024 - val_accuracy: 0.8250
# Epoch 34/500
# 7/7 - 0s - loss: 0.3088 - accuracy: 0.9000 - val_loss: 0.4860 - val_accuracy: 0.8250
# Epoch 35/500
# 7/7 - 0s - loss: 0.2996 - accuracy: 0.9000 - val_loss: 0.5035 - val_accuracy: 0.8000
# Epoch 36/500
# 7/7 - 0s - loss: 0.3459 - accuracy: 0.8700 - val_loss: 0.5468 - val_accuracy: 0.8000
# Epoch 37/500
# 7/7 - 0s - loss: 0.2664 - accuracy: 0.9300 - val_loss: 0.4893 - val_accuracy: 0.7750
# Epoch 38/500
# 7/7 - 0s - loss: 0.2550 - accuracy: 0.9300 - val_loss: 0.4806 - val_accuracy: 0.8250
# Epoch 39/500
# 7/7 - 0s - loss: 0.2076 - accuracy: 0.9350 - val_loss: 0.4922 - val_accuracy: 0.8250
# Epoch 40/500
# 7/7 - 0s - loss: 0.1767 - accuracy: 0.9500 - val_loss: 0.5157 - val_accuracy: 0.7750
# Epoch 41/500
# 7/7 - 0s - loss: 0.1621 - accuracy: 0.9500 - val_loss: 0.6608 - val_accuracy: 0.7000
# Epoch 42/500
# 7/7 - 0s - loss: 0.1543 - accuracy: 0.9500 - val_loss: 0.6738 - val_accuracy: 0.8000
# Epoch 43/500
# 7/7 - 0s - loss: 0.0879 - accuracy: 0.9750 - val_loss: 0.5763 - val_accuracy: 0.7750
# Epoch 44/500
# 7/7 - 0s - loss: 0.0637 - accuracy: 0.9800 - val_loss: 1.1124 - val_accuracy: 0.6000
# Epoch 45/500
# 7/7 - 0s - loss: 0.3188 - accuracy: 0.8950 - val_loss: 0.7971 - val_accuracy: 0.8250
# Epoch 46/500
# 7/7 - 0s - loss: 0.2510 - accuracy: 0.9200 - val_loss: 0.6061 - val_accuracy: 0.8000
# Epoch 47/500
# 7/7 - 0s - loss: 0.1997 - accuracy: 0.9250 - val_loss: 0.4939 - val_accuracy: 0.8000
# Epoch 48/500
# 7/7 - 0s - loss: 0.1528 - accuracy: 0.9700 - val_loss: 0.5029 - val_accuracy: 0.8250
# Epoch 49/500
# 7/7 - 0s - loss: 0.0906 - accuracy: 0.9800 - val_loss: 0.5592 - val_accuracy: 0.8250
# Epoch 50/500
# 7/7 - 0s - loss: 0.0571 - accuracy: 0.9750 - val_loss: 0.7862 - val_accuracy: 0.7000
# Epoch 51/500
# 7/7 - 0s - loss: 0.0243 - accuracy: 0.9950 - val_loss: 1.8531 - val_accuracy: 0.7250
# Epoch 52/500
# 7/7 - 0s - loss: 0.1536 - accuracy: 0.9650 - val_loss: 0.8958 - val_accuracy: 0.7000
# Epoch 53/500
# 7/7 - 0s - loss: 0.0781 - accuracy: 0.9750 - val_loss: 0.7297 - val_accuracy: 0.8250
# Epoch 54/500
# 7/7 - 0s - loss: 0.0578 - accuracy: 0.9800 - val_loss: 0.6951 - val_accuracy: 0.7250
# Epoch 55/500
# 7/7 - 0s - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.7528 - val_accuracy: 0.8000
# Epoch 56/500
# 7/7 - 0s - loss: 0.0358 - accuracy: 0.9850 - val_loss: 0.6435 - val_accuracy: 0.8250
# Epoch 57/500
# 7/7 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.8500
# Epoch 58/500
# 7/7 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7766 - val_accuracy: 0.8500
# Epoch 59/500
# 7/7 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7506 - val_accuracy: 0.8000
# Epoch 60/500
# 7/7 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8279 - val_accuracy: 0.8250
# Epoch 61/500
# 7/7 - 0s - loss: 9.5712e-04 - accuracy: 1.0000 - val_loss: 0.9725 - val_accuracy: 0.8500
# Epoch 62/500
# 7/7 - 0s - loss: 7.5220e-04 - accuracy: 1.0000 - val_loss: 1.0616 - val_accuracy: 0.8250
# Epoch 63/500
# 7/7 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9161 - val_accuracy: 0.8000
# Epoch 1/500
# 7/7 - 2s - loss: 0.6089 - accuracy: 0.7150 - val_loss: 0.5326 - val_accuracy: 0.7000
# Epoch 2/500
# 7/7 - 0s - loss: 0.5853 - accuracy: 0.7050 - val_loss: 0.5216 - val_accuracy: 0.7000
# Epoch 3/500
# 7/7 - 0s - loss: 0.5796 - accuracy: 0.7050 - val_loss: 0.5314 - val_accuracy: 0.7000
# Epoch 4/500
# 7/7 - 0s - loss: 0.5638 - accuracy: 0.7050 - val_loss: 0.4988 - val_accuracy: 0.7000
# Epoch 5/500
# 7/7 - 0s - loss: 0.5604 - accuracy: 0.7050 - val_loss: 0.4894 - val_accuracy: 0.7000
# Epoch 6/500
# 7/7 - 0s - loss: 0.5502 - accuracy: 0.7100 - val_loss: 0.4938 - val_accuracy: 0.8500
# Epoch 7/500
# 7/7 - 0s - loss: 0.5581 - accuracy: 0.7800 - val_loss: 0.4847 - val_accuracy: 0.8500
# Epoch 8/500
# 7/7 - 0s - loss: 0.5362 - accuracy: 0.7800 - val_loss: 0.4641 - val_accuracy: 0.8500
# Epoch 9/500
# 7/7 - 0s - loss: 0.5429 - accuracy: 0.7800 - val_loss: 0.4498 - val_accuracy: 0.8500
# Epoch 10/500
# 7/7 - 0s - loss: 0.5313 - accuracy: 0.7800 - val_loss: 0.4432 - val_accuracy: 0.8500
# Epoch 11/500
# 7/7 - 0s - loss: 0.5444 - accuracy: 0.7750 - val_loss: 0.4989 - val_accuracy: 0.8500
# Epoch 12/500
# 7/7 - 0s - loss: 0.5024 - accuracy: 0.7800 - val_loss: 0.4257 - val_accuracy: 0.8500
# Epoch 13/500
# 7/7 - 0s - loss: 0.5139 - accuracy: 0.7750 - val_loss: 0.4351 - val_accuracy: 0.8500
# Epoch 14/500
# 7/7 - 0s - loss: 0.5081 - accuracy: 0.7950 - val_loss: 0.4507 - val_accuracy: 0.8500
# Epoch 15/500
# 7/7 - 0s - loss: 0.4775 - accuracy: 0.8050 - val_loss: 0.4265 - val_accuracy: 0.8500
# Epoch 16/500
# 7/7 - 0s - loss: 0.4566 - accuracy: 0.8300 - val_loss: 0.4363 - val_accuracy: 0.8500
# Epoch 17/500
# 7/7 - 0s - loss: 0.3681 - accuracy: 0.8750 - val_loss: 0.5435 - val_accuracy: 0.7500
# Epoch 18/500
# 7/7 - 0s - loss: 0.4269 - accuracy: 0.8150 - val_loss: 0.4333 - val_accuracy: 0.8500
# Epoch 19/500
# 7/7 - 0s - loss: 0.3217 - accuracy: 0.8800 - val_loss: 0.4520 - val_accuracy: 0.8250
# Epoch 20/500
# 7/7 - 0s - loss: 0.4115 - accuracy: 0.8500 - val_loss: 0.5423 - val_accuracy: 0.7750
# Epoch 21/500
# 7/7 - 0s - loss: 0.4144 - accuracy: 0.8400 - val_loss: 0.8023 - val_accuracy: 0.7250
# Epoch 22/500
# 7/7 - 0s - loss: 0.3670 - accuracy: 0.8800 - val_loss: 0.4517 - val_accuracy: 0.8250
# Epoch 23/500
# 7/7 - 0s - loss: 0.2704 - accuracy: 0.9150 - val_loss: 0.4823 - val_accuracy: 0.8250
# Epoch 24/500
# 7/7 - 0s - loss: 0.2364 - accuracy: 0.9250 - val_loss: 0.5312 - val_accuracy: 0.8500
# Epoch 25/500
# 7/7 - 0s - loss: 0.2473 - accuracy: 0.9000 - val_loss: 1.2171 - val_accuracy: 0.3250
# Epoch 26/500
# 7/7 - 0s - loss: 0.4103 - accuracy: 0.8200 - val_loss: 0.5042 - val_accuracy: 0.8000
# Epoch 27/500
# 7/7 - 0s - loss: 0.2517 - accuracy: 0.9300 - val_loss: 0.4819 - val_accuracy: 0.8250
# Epoch 28/500
# 7/7 - 0s - loss: 0.2111 - accuracy: 0.9350 - val_loss: 0.8589 - val_accuracy: 0.6000
# Epoch 29/500
# 7/7 - 0s - loss: 0.1366 - accuracy: 0.9500 - val_loss: 0.9685 - val_accuracy: 0.6000
# Epoch 30/500
# 7/7 - 0s - loss: 0.0881 - accuracy: 0.9700 - val_loss: 0.8631 - val_accuracy: 0.7750
# Epoch 31/500
# 7/7 - 0s - loss: 0.1077 - accuracy: 0.9700 - val_loss: 0.8533 - val_accuracy: 0.8000
# Epoch 32/500
# 7/7 - 0s - loss: 0.0925 - accuracy: 0.9600 - val_loss: 1.5814 - val_accuracy: 0.4250
# Epoch 33/500
# 7/7 - 0s - loss: 0.1050 - accuracy: 0.9650 - val_loss: 0.8228 - val_accuracy: 0.8000
# Epoch 34/500
# 7/7 - 0s - loss: 0.0881 - accuracy: 0.9650 - val_loss: 0.9416 - val_accuracy: 0.7500
# Epoch 35/500
# 7/7 - 0s - loss: 0.0537 - accuracy: 0.9750 - val_loss: 0.9037 - val_accuracy: 0.8000
# Epoch 36/500
# 7/7 - 0s - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.9824 - val_accuracy: 0.8000
# Epoch 37/500
# 7/7 - 0s - loss: 0.0586 - accuracy: 0.9850 - val_loss: 1.3910 - val_accuracy: 0.6750
# Epoch 1/500
# 7/7 - 2s - loss: 0.6090 - accuracy: 0.7500 - val_loss: 0.7697 - val_accuracy: 0.6250
# Epoch 2/500
# 7/7 - 0s - loss: 0.5252 - accuracy: 0.7800 - val_loss: 0.6393 - val_accuracy: 0.6250
# Epoch 3/500
# 7/7 - 0s - loss: 0.5281 - accuracy: 0.7800 - val_loss: 0.6699 - val_accuracy: 0.6250
# Epoch 4/500
# 7/7 - 0s - loss: 0.5182 - accuracy: 0.7800 - val_loss: 0.6739 - val_accuracy: 0.6250
# Epoch 5/500
# 7/7 - 0s - loss: 0.5122 - accuracy: 0.7800 - val_loss: 0.6708 - val_accuracy: 0.6250
# Epoch 6/500
# 7/7 - 0s - loss: 0.5452 - accuracy: 0.7800 - val_loss: 0.6544 - val_accuracy: 0.6250
# Epoch 7/500
# 7/7 - 0s - loss: 0.5194 - accuracy: 0.7800 - val_loss: 0.6512 - val_accuracy: 0.6250
# Epoch 8/500
# 7/7 - 0s - loss: 0.5138 - accuracy: 0.7800 - val_loss: 0.6971 - val_accuracy: 0.6250
# Epoch 9/500
# 7/7 - 0s - loss: 0.5041 - accuracy: 0.7800 - val_loss: 0.6552 - val_accuracy: 0.6250
# Epoch 10/500
# 7/7 - 0s - loss: 0.5135 - accuracy: 0.7800 - val_loss: 0.6765 - val_accuracy: 0.6250
# Epoch 11/500
# 7/7 - 0s - loss: 0.4976 - accuracy: 0.7800 - val_loss: 0.6367 - val_accuracy: 0.6250
# Epoch 12/500
# 7/7 - 0s - loss: 0.5172 - accuracy: 0.7800 - val_loss: 0.6613 - val_accuracy: 0.6250
# Epoch 13/500
# 7/7 - 0s - loss: 0.5206 - accuracy: 0.7800 - val_loss: 0.6339 - val_accuracy: 0.6250
# Epoch 14/500
# 7/7 - 0s - loss: 0.5173 - accuracy: 0.7800 - val_loss: 0.6896 - val_accuracy: 0.6250
# Epoch 15/500
# 7/7 - 0s - loss: 0.5029 - accuracy: 0.7800 - val_loss: 0.6809 - val_accuracy: 0.6250
# Epoch 16/500
# 7/7 - 0s - loss: 0.4932 - accuracy: 0.7800 - val_loss: 0.6425 - val_accuracy: 0.6250
# Epoch 17/500
# 7/7 - 0s - loss: 0.4888 - accuracy: 0.7800 - val_loss: 0.6521 - val_accuracy: 0.6250
# Epoch 18/500
# 7/7 - 0s - loss: 0.4732 - accuracy: 0.7800 - val_loss: 0.6194 - val_accuracy: 0.6250
# Epoch 19/500
# 7/7 - 0s - loss: 0.4548 - accuracy: 0.7800 - val_loss: 0.7225 - val_accuracy: 0.6250
# Epoch 20/500
# 7/7 - 0s - loss: 0.4796 - accuracy: 0.7800 - val_loss: 0.6531 - val_accuracy: 0.6250
# Epoch 21/500
# 7/7 - 0s - loss: 0.4872 - accuracy: 0.7800 - val_loss: 0.6008 - val_accuracy: 0.6250
# Epoch 22/500
# 7/7 - 0s - loss: 0.5538 - accuracy: 0.8150 - val_loss: 0.6123 - val_accuracy: 0.6250
# Epoch 23/500
# 7/7 - 0s - loss: 0.4720 - accuracy: 0.7800 - val_loss: 0.7417 - val_accuracy: 0.6250
# Epoch 24/500
# 7/7 - 0s - loss: 0.4842 - accuracy: 0.7950 - val_loss: 0.6177 - val_accuracy: 0.6750
# Epoch 25/500
# 7/7 - 0s - loss: 0.4032 - accuracy: 0.8200 - val_loss: 0.6095 - val_accuracy: 0.6250
# Epoch 26/500
# 7/7 - 0s - loss: 0.3503 - accuracy: 0.8450 - val_loss: 0.5871 - val_accuracy: 0.7500
# Epoch 27/500
# 7/7 - 0s - loss: 0.3172 - accuracy: 0.8650 - val_loss: 0.7440 - val_accuracy: 0.5500
# Epoch 28/500
# 7/7 - 0s - loss: 0.3596 - accuracy: 0.8650 - val_loss: 0.7292 - val_accuracy: 0.6500
# Epoch 29/500
# 7/7 - 0s - loss: 0.2824 - accuracy: 0.8950 - val_loss: 0.7430 - val_accuracy: 0.6250
# Epoch 30/500
# 7/7 - 0s - loss: 0.3068 - accuracy: 0.8750 - val_loss: 0.6453 - val_accuracy: 0.6500
# Epoch 31/500
# 7/7 - 0s - loss: 0.2081 - accuracy: 0.9150 - val_loss: 1.1302 - val_accuracy: 0.6000
# Epoch 32/500
# 7/7 - 0s - loss: 0.2887 - accuracy: 0.9050 - val_loss: 0.7216 - val_accuracy: 0.6250
# Epoch 33/500
# 7/7 - 0s - loss: 0.2231 - accuracy: 0.9200 - val_loss: 0.6994 - val_accuracy: 0.7250
# Epoch 34/500
# 7/7 - 0s - loss: 0.1826 - accuracy: 0.9400 - val_loss: 0.7457 - val_accuracy: 0.6750
# Epoch 35/500
# 7/7 - 0s - loss: 0.1390 - accuracy: 0.9600 - val_loss: 0.9110 - val_accuracy: 0.7000
# Epoch 36/500
# 7/7 - 0s - loss: 0.1398 - accuracy: 0.9450 - val_loss: 0.9383 - val_accuracy: 0.7500
# Epoch 37/500
# 7/7 - 0s - loss: 0.0854 - accuracy: 0.9750 - val_loss: 1.0264 - val_accuracy: 0.6750
# Epoch 38/500
# 7/7 - 0s - loss: 0.0821 - accuracy: 0.9750 - val_loss: 1.1916 - val_accuracy: 0.6500
# Epoch 39/500
# 7/7 - 0s - loss: 0.0619 - accuracy: 0.9850 - val_loss: 1.3038 - val_accuracy: 0.7000
# Epoch 40/500
# 7/7 - 0s - loss: 0.0850 - accuracy: 0.9700 - val_loss: 1.3230 - val_accuracy: 0.7000
# Epoch 41/500
# 7/7 - 0s - loss: 0.0931 - accuracy: 0.9650 - val_loss: 1.0860 - val_accuracy: 0.6500
# Epoch 42/500
# 7/7 - 0s - loss: 0.0289 - accuracy: 0.9900 - val_loss: 1.1712 - val_accuracy: 0.7000
# Epoch 43/500
# 7/7 - 0s - loss: 0.0385 - accuracy: 0.9800 - val_loss: 1.2948 - val_accuracy: 0.6750
# Epoch 44/500
# 7/7 - 0s - loss: 0.0209 - accuracy: 0.9900 - val_loss: 1.5995 - val_accuracy: 0.6500
# Epoch 45/500
# 7/7 - 0s - loss: 0.0751 - accuracy: 0.9700 - val_loss: 1.6106 - val_accuracy: 0.6500
# Epoch 46/500
# 7/7 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.7000
# Epoch 47/500
# 7/7 - 0s - loss: 0.0219 - accuracy: 0.9900 - val_loss: 1.6564 - val_accuracy: 0.6500
# Epoch 48/500
# 7/7 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.7067 - val_accuracy: 0.6750
# Epoch 49/500
# 7/7 - 0s - loss: 0.0099 - accuracy: 0.9950 - val_loss: 1.9817 - val_accuracy: 0.6500
# Epoch 50/500
# 7/7 - 0s - loss: 0.0234 - accuracy: 0.9900 - val_loss: 1.9534 - val_accuracy: 0.6250
# Epoch 51/500
# 7/7 - 0s - loss: 0.0078 - accuracy: 0.9950 - val_loss: 2.3239 - val_accuracy: 0.6250
# Epoch 1/500
# 7/7 - 2s - loss: 0.5999 - accuracy: 0.6750 - val_loss: 0.7846 - val_accuracy: 0.7500
# Epoch 2/500
# 7/7 - 0s - loss: 0.6058 - accuracy: 0.7150 - val_loss: 0.6041 - val_accuracy: 0.7500
# Epoch 3/500
# 7/7 - 0s - loss: 0.5913 - accuracy: 0.7150 - val_loss: 0.5689 - val_accuracy: 0.7500
# Epoch 4/500
# 7/7 - 0s - loss: 0.5743 - accuracy: 0.7150 - val_loss: 0.5792 - val_accuracy: 0.7500
# Epoch 5/500
# 7/7 - 0s - loss: 0.5635 - accuracy: 0.7150 - val_loss: 0.5861 - val_accuracy: 0.7500
# Epoch 6/500
# 7/7 - 0s - loss: 0.5526 - accuracy: 0.7150 - val_loss: 0.5791 - val_accuracy: 0.7500
# Epoch 7/500
# 7/7 - 0s - loss: 0.5586 - accuracy: 0.7150 - val_loss: 0.5760 - val_accuracy: 0.7500
# Epoch 8/500
# 7/7 - 0s - loss: 0.5368 - accuracy: 0.7150 - val_loss: 0.5787 - val_accuracy: 0.7250
# Epoch 9/500
# 7/7 - 0s - loss: 0.5310 - accuracy: 0.7500 - val_loss: 0.5832 - val_accuracy: 0.7500
# Epoch 10/500
# 7/7 - 0s - loss: 0.5340 - accuracy: 0.7650 - val_loss: 0.5840 - val_accuracy: 0.7000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5252 - accuracy: 0.7550 - val_loss: 0.5954 - val_accuracy: 0.7000
# Epoch 12/500
# 7/7 - 0s - loss: 0.5060 - accuracy: 0.7850 - val_loss: 0.6162 - val_accuracy: 0.7000
# Epoch 13/500
# 7/7 - 0s - loss: 0.5065 - accuracy: 0.7650 - val_loss: 0.6359 - val_accuracy: 0.7000
# Epoch 14/500
# 7/7 - 0s - loss: 0.4811 - accuracy: 0.7800 - val_loss: 0.6034 - val_accuracy: 0.7000
# Epoch 15/500
# 7/7 - 0s - loss: 0.4655 - accuracy: 0.7850 - val_loss: 0.8295 - val_accuracy: 0.5500
# Epoch 16/500
# 7/7 - 0s - loss: 0.4973 - accuracy: 0.7550 - val_loss: 0.5818 - val_accuracy: 0.7500
# Epoch 17/500
# 7/7 - 0s - loss: 0.4679 - accuracy: 0.8100 - val_loss: 0.6663 - val_accuracy: 0.7250
# Epoch 18/500
# 7/7 - 0s - loss: 0.4305 - accuracy: 0.8050 - val_loss: 0.6897 - val_accuracy: 0.6500
# Epoch 19/500
# 7/7 - 0s - loss: 0.3851 - accuracy: 0.8250 - val_loss: 0.9103 - val_accuracy: 0.5750
# Epoch 20/500
# 7/7 - 0s - loss: 0.3254 - accuracy: 0.8800 - val_loss: 0.6687 - val_accuracy: 0.7250
# Epoch 21/500
# 7/7 - 0s - loss: 0.2637 - accuracy: 0.9200 - val_loss: 0.7696 - val_accuracy: 0.7500
# Epoch 22/500
# 7/7 - 0s - loss: 0.4384 - accuracy: 0.8500 - val_loss: 1.6862 - val_accuracy: 0.4750
# Epoch 23/500
# 7/7 - 0s - loss: 0.4392 - accuracy: 0.8150 - val_loss: 0.6943 - val_accuracy: 0.7250
# Epoch 24/500
# 7/7 - 0s - loss: 0.4486 - accuracy: 0.8150 - val_loss: 0.6099 - val_accuracy: 0.7250
# Epoch 25/500
# 7/7 - 0s - loss: 0.3717 - accuracy: 0.8700 - val_loss: 0.6734 - val_accuracy: 0.7000
# Epoch 26/500
# 7/7 - 0s - loss: 0.2532 - accuracy: 0.9100 - val_loss: 1.3531 - val_accuracy: 0.5500
# Epoch 27/500
# 7/7 - 0s - loss: 0.3107 - accuracy: 0.8750 - val_loss: 0.7635 - val_accuracy: 0.6750
# Epoch 28/500
# 7/7 - 0s - loss: 0.1811 - accuracy: 0.9300 - val_loss: 1.5320 - val_accuracy: 0.3500
# Epoch 1/500
# 7/7 - 2s - loss: 0.6067 - accuracy: 0.6550 - val_loss: 0.5503 - val_accuracy: 0.7750
# Epoch 2/500
# 7/7 - 0s - loss: 0.5773 - accuracy: 0.7150 - val_loss: 0.5468 - val_accuracy: 0.7750
# Epoch 3/500
# 7/7 - 0s - loss: 0.5505 - accuracy: 0.7150 - val_loss: 0.4487 - val_accuracy: 0.7750
# Epoch 4/500
# 7/7 - 0s - loss: 0.5386 - accuracy: 0.7150 - val_loss: 0.4696 - val_accuracy: 0.7750
# Epoch 5/500
# 7/7 - 0s - loss: 0.5094 - accuracy: 0.7250 - val_loss: 0.4245 - val_accuracy: 0.8250
# Epoch 6/500
# 7/7 - 0s - loss: 0.4952 - accuracy: 0.7750 - val_loss: 0.4320 - val_accuracy: 0.8000
# Epoch 7/500
# 7/7 - 0s - loss: 0.4938 - accuracy: 0.8000 - val_loss: 0.4186 - val_accuracy: 0.8000
# Epoch 8/500
# 7/7 - 0s - loss: 0.5130 - accuracy: 0.8000 - val_loss: 0.4396 - val_accuracy: 0.8000
# Epoch 9/500
# 7/7 - 0s - loss: 0.4693 - accuracy: 0.8000 - val_loss: 0.4239 - val_accuracy: 0.8000
# Epoch 10/500
# 7/7 - 0s - loss: 0.4730 - accuracy: 0.8000 - val_loss: 0.4379 - val_accuracy: 0.8000
# Epoch 11/500
# 7/7 - 0s - loss: 0.4604 - accuracy: 0.8000 - val_loss: 0.4114 - val_accuracy: 0.8500
# Epoch 12/500
# 7/7 - 0s - loss: 0.4747 - accuracy: 0.7650 - val_loss: 0.4639 - val_accuracy: 0.8000
# Epoch 13/500
# 7/7 - 0s - loss: 0.4960 - accuracy: 0.7850 - val_loss: 0.4136 - val_accuracy: 0.8000
# Epoch 14/500
# 7/7 - 0s - loss: 0.4613 - accuracy: 0.8000 - val_loss: 0.4239 - val_accuracy: 0.8000
# Epoch 15/500
# 7/7 - 0s - loss: 0.4479 - accuracy: 0.8000 - val_loss: 0.4233 - val_accuracy: 0.8000
# Epoch 16/500
# 7/7 - 0s - loss: 0.4707 - accuracy: 0.8000 - val_loss: 0.4539 - val_accuracy: 0.8000
# Epoch 17/500
# 7/7 - 0s - loss: 0.4584 - accuracy: 0.8300 - val_loss: 0.4401 - val_accuracy: 0.8000
# Epoch 18/500
# 7/7 - 0s - loss: 0.4286 - accuracy: 0.8250 - val_loss: 0.4377 - val_accuracy: 0.8000
# Epoch 19/500
# 7/7 - 0s - loss: 0.4449 - accuracy: 0.7950 - val_loss: 0.4146 - val_accuracy: 0.8500
# Epoch 20/500
# 7/7 - 0s - loss: 0.4019 - accuracy: 0.8300 - val_loss: 0.5047 - val_accuracy: 0.7750
# Epoch 21/500
# 7/7 - 0s - loss: 0.3749 - accuracy: 0.8400 - val_loss: 0.4236 - val_accuracy: 0.8500
# Epoch 22/500
# 7/7 - 0s - loss: 0.3530 - accuracy: 0.8700 - val_loss: 0.4876 - val_accuracy: 0.8250
# Epoch 23/500
# 7/7 - 0s - loss: 0.2921 - accuracy: 0.8950 - val_loss: 0.5963 - val_accuracy: 0.7750
# Epoch 24/500
# 7/7 - 0s - loss: 0.2288 - accuracy: 0.9200 - val_loss: 0.4915 - val_accuracy: 0.8250
# Epoch 25/500
# 7/7 - 0s - loss: 0.1619 - accuracy: 0.9500 - val_loss: 0.4987 - val_accuracy: 0.8500
# Epoch 26/500
# 7/7 - 0s - loss: 0.1378 - accuracy: 0.9550 - val_loss: 0.7065 - val_accuracy: 0.8250
# Epoch 27/500
# 7/7 - 0s - loss: 0.2873 - accuracy: 0.9050 - val_loss: 0.8461 - val_accuracy: 0.7750
# Epoch 28/500
# 7/7 - 0s - loss: 0.3327 - accuracy: 0.8800 - val_loss: 0.6954 - val_accuracy: 0.7750
# Epoch 29/500
# 7/7 - 0s - loss: 0.3390 - accuracy: 0.8850 - val_loss: 0.4299 - val_accuracy: 0.8000
# Epoch 30/500
# 7/7 - 0s - loss: 0.2666 - accuracy: 0.9450 - val_loss: 0.6340 - val_accuracy: 0.7750
# Epoch 31/500
# 7/7 - 0s - loss: 0.2311 - accuracy: 0.9450 - val_loss: 0.6278 - val_accuracy: 0.8000
# Epoch 32/500
# 7/7 - 0s - loss: 0.1858 - accuracy: 0.9350 - val_loss: 0.6941 - val_accuracy: 0.8000
# Epoch 33/500
# 7/7 - 0s - loss: 0.1558 - accuracy: 0.9450 - val_loss: 2.0710 - val_accuracy: 0.5250
# Epoch 34/500
# 7/7 - 0s - loss: 0.3886 - accuracy: 0.8400 - val_loss: 0.4874 - val_accuracy: 0.8250
# Epoch 35/500
# 7/7 - 0s - loss: 0.1886 - accuracy: 0.9250 - val_loss: 0.8641 - val_accuracy: 0.7250
# Epoch 36/500
# 7/7 - 0s - loss: 0.1521 - accuracy: 0.9500 - val_loss: 0.4967 - val_accuracy: 0.8000
# Epoch 1/500
# 7/7 - 2s - loss: 0.6375 - accuracy: 0.6400 - val_loss: 0.8288 - val_accuracy: 0.5250
# Epoch 2/500
# 7/7 - 0s - loss: 0.6111 - accuracy: 0.6850 - val_loss: 0.7174 - val_accuracy: 0.5250
# Epoch 3/500
# 7/7 - 0s - loss: 0.5886 - accuracy: 0.6850 - val_loss: 0.7646 - val_accuracy: 0.5250
# Epoch 4/500
# 7/7 - 0s - loss: 0.5747 - accuracy: 0.6850 - val_loss: 0.6954 - val_accuracy: 0.5250
# Epoch 5/500
# 7/7 - 0s - loss: 0.5686 - accuracy: 0.6850 - val_loss: 0.7548 - val_accuracy: 0.5250
# Epoch 6/500
# 7/7 - 0s - loss: 0.5637 - accuracy: 0.7550 - val_loss: 0.7273 - val_accuracy: 0.5750
# Epoch 7/500
# 7/7 - 0s - loss: 0.5788 - accuracy: 0.7550 - val_loss: 0.7061 - val_accuracy: 0.5750
# Epoch 8/500
# 7/7 - 0s - loss: 0.5721 - accuracy: 0.7500 - val_loss: 0.7351 - val_accuracy: 0.5750
# Epoch 9/500
# 7/7 - 0s - loss: 0.5586 - accuracy: 0.7600 - val_loss: 0.7149 - val_accuracy: 0.5750
# Epoch 10/500
# 7/7 - 0s - loss: 0.5388 - accuracy: 0.7550 - val_loss: 0.6715 - val_accuracy: 0.6000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5315 - accuracy: 0.7500 - val_loss: 0.6783 - val_accuracy: 0.6750
# Epoch 12/500
# 7/7 - 0s - loss: 0.5099 - accuracy: 0.7800 - val_loss: 1.0284 - val_accuracy: 0.5750
# Epoch 13/500
# 7/7 - 0s - loss: 0.5643 - accuracy: 0.7650 - val_loss: 0.6506 - val_accuracy: 0.6000
# Epoch 14/500
# 7/7 - 0s - loss: 0.5248 - accuracy: 0.7700 - val_loss: 0.6803 - val_accuracy: 0.6000
# Epoch 15/500
# 7/7 - 1s - loss: 0.5028 - accuracy: 0.7750 - val_loss: 0.7319 - val_accuracy: 0.6000
# Epoch 16/500
# 7/7 - 0s - loss: 0.4972 - accuracy: 0.7900 - val_loss: 0.9451 - val_accuracy: 0.5750
# Epoch 17/500
# 7/7 - 0s - loss: 0.4930 - accuracy: 0.8050 - val_loss: 0.6048 - val_accuracy: 0.7000
# Epoch 18/500
# 7/7 - 0s - loss: 0.4202 - accuracy: 0.8400 - val_loss: 0.6468 - val_accuracy: 0.6250
# Epoch 19/500
# 7/7 - 0s - loss: 0.3489 - accuracy: 0.8550 - val_loss: 1.7417 - val_accuracy: 0.5500
# Epoch 20/500
# 7/7 - 0s - loss: 0.4237 - accuracy: 0.8050 - val_loss: 0.8863 - val_accuracy: 0.6500
# Epoch 21/500
# 7/7 - 0s - loss: 0.3144 - accuracy: 0.8750 - val_loss: 0.7460 - val_accuracy: 0.6000
# Epoch 22/500
# 7/7 - 0s - loss: 0.2178 - accuracy: 0.9250 - val_loss: 1.1127 - val_accuracy: 0.6000
# Epoch 23/500
# 7/7 - 0s - loss: 0.2698 - accuracy: 0.9000 - val_loss: 1.5400 - val_accuracy: 0.5750
# Epoch 24/500
# 7/7 - 0s - loss: 0.1536 - accuracy: 0.9550 - val_loss: 0.9591 - val_accuracy: 0.6250
# Epoch 25/500
# 7/7 - 0s - loss: 0.1126 - accuracy: 0.9700 - val_loss: 1.0201 - val_accuracy: 0.6250
# Epoch 26/500
# 7/7 - 0s - loss: 0.0669 - accuracy: 0.9850 - val_loss: 1.0027 - val_accuracy: 0.6250
# Epoch 27/500
# 7/7 - 1s - loss: 0.0341 - accuracy: 0.9900 - val_loss: 1.3917 - val_accuracy: 0.5750
# Epoch 28/500
# 7/7 - 0s - loss: 0.0372 - accuracy: 0.9850 - val_loss: 1.3543 - val_accuracy: 0.7000
# Epoch 29/500
# 7/7 - 0s - loss: 0.0149 - accuracy: 0.9950 - val_loss: 2.1712 - val_accuracy: 0.6000
# Epoch 30/500
# 7/7 - 0s - loss: 0.0669 - accuracy: 0.9850 - val_loss: 1.7794 - val_accuracy: 0.5000
# Epoch 31/500
# 7/7 - 0s - loss: 0.1020 - accuracy: 0.9600 - val_loss: 1.0831 - val_accuracy: 0.6500
# Epoch 32/500
# 7/7 - 0s - loss: 0.0933 - accuracy: 0.9750 - val_loss: 1.5908 - val_accuracy: 0.6500
# Epoch 33/500
# 7/7 - 0s - loss: 0.0570 - accuracy: 0.9650 - val_loss: 1.4288 - val_accuracy: 0.6750
# Epoch 34/500
# 7/7 - 0s - loss: 0.0843 - accuracy: 0.9750 - val_loss: 1.6307 - val_accuracy: 0.5750
# Epoch 35/500
# 7/7 - 0s - loss: 0.0397 - accuracy: 0.9950 - val_loss: 1.4878 - val_accuracy: 0.6250
# Epoch 36/500
# 7/7 - 0s - loss: 0.0315 - accuracy: 0.9850 - val_loss: 2.5081 - val_accuracy: 0.5750
# Epoch 37/500
# 7/7 - 0s - loss: 0.0836 - accuracy: 0.9650 - val_loss: 3.1482 - val_accuracy: 0.5750
# Epoch 38/500
# 7/7 - 0s - loss: 0.0595 - accuracy: 0.9800 - val_loss: 1.7812 - val_accuracy: 0.6000
# Epoch 39/500
# 7/7 - 0s - loss: 0.0117 - accuracy: 0.9950 - val_loss: 3.0974 - val_accuracy: 0.5250
# Epoch 40/500
# 7/7 - 0s - loss: 0.0209 - accuracy: 0.9950 - val_loss: 1.4554 - val_accuracy: 0.6500
# Epoch 41/500
# 7/7 - 0s - loss: 0.0136 - accuracy: 0.9950 - val_loss: 2.6380 - val_accuracy: 0.6250
# Epoch 42/500
# 7/7 - 0s - loss: 0.0069 - accuracy: 0.9950 - val_loss: 2.4780 - val_accuracy: 0.5250
# Epoch 1/500
# 7/7 - 2s - loss: 0.6222 - accuracy: 0.6850 - val_loss: 0.5799 - val_accuracy: 0.6750
# Epoch 2/500
# 7/7 - 0s - loss: 0.5545 - accuracy: 0.7250 - val_loss: 0.5826 - val_accuracy: 0.6750
# Epoch 3/500
# 7/7 - 0s - loss: 0.5568 - accuracy: 0.7250 - val_loss: 0.5657 - val_accuracy: 0.6750
# Epoch 4/500
# 7/7 - 0s - loss: 0.5498 - accuracy: 0.7250 - val_loss: 0.5628 - val_accuracy: 0.6750
# Epoch 5/500
# 7/7 - 0s - loss: 0.5309 - accuracy: 0.7250 - val_loss: 0.5460 - val_accuracy: 0.6750
# Epoch 6/500
# 7/7 - 0s - loss: 0.5319 - accuracy: 0.7300 - val_loss: 0.5412 - val_accuracy: 0.8000
# Epoch 7/500
# 7/7 - 0s - loss: 0.5220 - accuracy: 0.8000 - val_loss: 0.5438 - val_accuracy: 0.8000
# Epoch 8/500
# 7/7 - 0s - loss: 0.5348 - accuracy: 0.7900 - val_loss: 0.5414 - val_accuracy: 0.8000
# Epoch 9/500
# 7/7 - 0s - loss: 0.5376 - accuracy: 0.8000 - val_loss: 0.5420 - val_accuracy: 0.8000
# Epoch 10/500
# 7/7 - 0s - loss: 0.4827 - accuracy: 0.8000 - val_loss: 0.6195 - val_accuracy: 0.8000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5186 - accuracy: 0.8000 - val_loss: 0.5539 - val_accuracy: 0.8000
# Epoch 12/500
# 7/7 - 0s - loss: 0.5132 - accuracy: 0.8000 - val_loss: 0.5364 - val_accuracy: 0.8000
# Epoch 13/500
# 7/7 - 0s - loss: 0.4976 - accuracy: 0.8000 - val_loss: 0.5400 - val_accuracy: 0.8000
# Epoch 14/500
# 7/7 - 0s - loss: 0.4849 - accuracy: 0.8000 - val_loss: 0.5212 - val_accuracy: 0.8000
# Epoch 15/500
# 7/7 - 0s - loss: 0.5026 - accuracy: 0.8000 - val_loss: 0.5571 - val_accuracy: 0.8000
# Epoch 16/500
# 7/7 - 0s - loss: 0.4764 - accuracy: 0.7900 - val_loss: 0.6030 - val_accuracy: 0.8000
# Epoch 17/500
# 7/7 - 0s - loss: 0.4757 - accuracy: 0.8000 - val_loss: 0.5652 - val_accuracy: 0.8000
# Epoch 18/500
# 7/7 - 0s - loss: 0.4744 - accuracy: 0.8000 - val_loss: 0.5749 - val_accuracy: 0.8000
# Epoch 19/500
# 7/7 - 0s - loss: 0.4505 - accuracy: 0.8000 - val_loss: 0.5764 - val_accuracy: 0.8000
# Epoch 20/500
# 7/7 - 0s - loss: 0.4390 - accuracy: 0.8200 - val_loss: 0.5735 - val_accuracy: 0.8000
# Epoch 21/500
# 7/7 - 0s - loss: 0.4078 - accuracy: 0.8250 - val_loss: 0.6415 - val_accuracy: 0.8000
# Epoch 22/500
# 7/7 - 0s - loss: 0.3770 - accuracy: 0.8250 - val_loss: 0.6891 - val_accuracy: 0.7750
# Epoch 23/500
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8700 - val_loss: 0.8131 - val_accuracy: 0.7500
# Epoch 24/500
# 7/7 - 0s - loss: 0.3016 - accuracy: 0.8750 - val_loss: 1.2735 - val_accuracy: 0.4250
# Epoch 25/500
# 7/7 - 0s - loss: 0.4987 - accuracy: 0.7600 - val_loss: 0.7551 - val_accuracy: 0.7500
# Epoch 26/500
# 7/7 - 0s - loss: 0.3958 - accuracy: 0.8350 - val_loss: 0.7479 - val_accuracy: 0.7000
# Epoch 27/500
# 7/7 - 0s - loss: 0.3750 - accuracy: 0.8250 - val_loss: 0.6408 - val_accuracy: 0.8000
# Epoch 28/500
# 7/7 - 0s - loss: 0.3153 - accuracy: 0.8700 - val_loss: 0.8406 - val_accuracy: 0.7250
# Epoch 29/500
# 7/7 - 0s - loss: 0.2329 - accuracy: 0.9000 - val_loss: 1.1757 - val_accuracy: 0.6750
# Epoch 30/500
# 7/7 - 0s - loss: 0.1931 - accuracy: 0.9300 - val_loss: 1.3055 - val_accuracy: 0.7250
# Epoch 31/500
# 7/7 - 0s - loss: 0.1947 - accuracy: 0.9350 - val_loss: 1.6058 - val_accuracy: 0.4500
# Epoch 32/500
# 7/7 - 0s - loss: 0.2556 - accuracy: 0.8800 - val_loss: 1.0039 - val_accuracy: 0.7750
# Epoch 33/500
# 7/7 - 0s - loss: 0.1701 - accuracy: 0.9350 - val_loss: 1.7584 - val_accuracy: 0.7000
# Epoch 34/500
# 7/7 - 0s - loss: 0.1334 - accuracy: 0.9550 - val_loss: 1.8641 - val_accuracy: 0.6500
# Epoch 35/500
# 7/7 - 0s - loss: 0.0579 - accuracy: 0.9850 - val_loss: 2.4836 - val_accuracy: 0.7000
# Epoch 36/500
# 7/7 - 0s - loss: 0.0796 - accuracy: 0.9700 - val_loss: 2.5915 - val_accuracy: 0.6500
# Epoch 37/500
# 7/7 - 0s - loss: 0.0741 - accuracy: 0.9700 - val_loss: 2.5140 - val_accuracy: 0.5000
# Epoch 38/500
# 7/7 - 0s - loss: 0.0430 - accuracy: 0.9850 - val_loss: 2.3704 - val_accuracy: 0.6500
# Epoch 39/500
# 7/7 - 0s - loss: 0.0409 - accuracy: 0.9800 - val_loss: 2.9121 - val_accuracy: 0.7000
# Epoch 1/500
# 7/7 - 2s - loss: 0.6564 - accuracy: 0.7000 - val_loss: 0.6892 - val_accuracy: 0.5750
# Epoch 2/500
# 7/7 - 0s - loss: 0.5813 - accuracy: 0.7000 - val_loss: 0.6599 - val_accuracy: 0.5750
# Epoch 3/500
# 7/7 - 0s - loss: 0.5948 - accuracy: 0.7000 - val_loss: 0.6585 - val_accuracy: 0.5750
# Epoch 4/500
# 7/7 - 0s - loss: 0.5852 - accuracy: 0.7000 - val_loss: 0.6418 - val_accuracy: 0.5750
# Epoch 5/500
# 7/7 - 0s - loss: 0.5792 - accuracy: 0.7000 - val_loss: 0.6782 - val_accuracy: 0.5750
# Epoch 6/500
# 7/7 - 0s - loss: 0.5694 - accuracy: 0.7000 - val_loss: 0.6431 - val_accuracy: 0.5750
# Epoch 7/500
# 7/7 - 0s - loss: 0.5600 - accuracy: 0.7100 - val_loss: 0.6589 - val_accuracy: 0.7000
# Epoch 8/500
# 7/7 - 0s - loss: 0.5615 - accuracy: 0.7500 - val_loss: 0.6339 - val_accuracy: 0.7000
# Epoch 9/500
# 7/7 - 0s - loss: 0.5475 - accuracy: 0.7550 - val_loss: 0.6358 - val_accuracy: 0.7000
# Epoch 10/500
# 7/7 - 0s - loss: 0.5620 - accuracy: 0.7550 - val_loss: 0.6329 - val_accuracy: 0.7000
# Epoch 11/500
# 7/7 - 0s - loss: 0.5450 - accuracy: 0.7550 - val_loss: 0.6664 - val_accuracy: 0.7000
# Epoch 12/500
# 7/7 - 0s - loss: 0.5486 - accuracy: 0.7550 - val_loss: 0.5978 - val_accuracy: 0.7000
# Epoch 13/500
# 7/7 - 0s - loss: 0.5332 - accuracy: 0.7500 - val_loss: 0.6632 - val_accuracy: 0.7000
# Epoch 14/500
# 7/7 - 0s - loss: 0.5370 - accuracy: 0.7550 - val_loss: 0.5977 - val_accuracy: 0.7250
# Epoch 15/500
# 7/7 - 0s - loss: 0.5475 - accuracy: 0.7500 - val_loss: 0.6491 - val_accuracy: 0.7250
# Epoch 16/500
# 7/7 - 0s - loss: 0.5230 - accuracy: 0.7550 - val_loss: 0.6220 - val_accuracy: 0.7000
# Epoch 17/500
# 7/7 - 0s - loss: 0.5109 - accuracy: 0.7550 - val_loss: 0.6122 - val_accuracy: 0.7000
# Epoch 18/500
# ...
# Epoch 31/500
# 7/7 - 1s - loss: 0.3390 - accuracy: 0.8900 - val_loss: 1.4016 - val_accuracy: 0.6250
# Epoch 32/500
# 7/7 - 0s - loss: 0.2865 - accuracy: 0.8950 - val_loss: 0.6402 - val_accuracy: 0.7500
# Epoch 33/500
# 7/7 - 0s - loss: 0.2521 - accuracy: 0.9050 - val_loss: 1.0503 - val_accuracy: 0.5750
# Epoch 34/500
# 7/7 - 1s - loss: 0.1470 - accuracy: 0.9450 - val_loss: 1.4866 - val_accuracy: 0.6250
# Epoch 35/500
# 7/7 - 1s - loss: 0.1326 - accuracy: 0.9550 - val_loss: 1.3729 - val_accuracy: 0.7000
# Epoch 36/500
# 7/7 - 0s - loss: 0.1052 - accuracy: 0.9500 - val_loss: 1.2876 - val_accuracy: 0.7500
# Epoch 37/500
# 7/7 - 0s - loss: 0.1245 - accuracy: 0.9500 - val_loss: 2.4109 - val_accuracy: 0.4000
# Epoch 38/500
# 7/7 - 0s - loss: 0.0697 - accuracy: 0.9700 - val_loss: 1.6134 - val_accuracy: 0.7000
# Epoch 39/500
# 7/7 - 1s - loss: 0.0366 - accuracy: 0.9850 - val_loss: 1.7211 - val_accuracy: 0.7750
# Epoch 40/500
# 7/7 - 0s - loss: 0.0182 - accuracy: 0.9900 - val_loss: 2.6302 - val_accuracy: 0.5750
# Epoch 41/500
# 7/7 - 1s - loss: 0.0355 - accuracy: 0.9850 - val_loss: 2.0610 - val_accuracy: 0.7500
# Epoch 42/500
# 7/7 - 0s - loss: 0.0161 - accuracy: 0.9950 - val_loss: 2.5077 - val_accuracy: 0.6000
# Epoch 43/500
# 7/7 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 2.6915 - val_accuracy: 0.5750
# Epoch 44/500
# 7/7 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.9304 - val_accuracy: 0.6000
# Epoch 45/500
# 7/7 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0382 - val_accuracy: 0.6500
# Epoch 46/500
# 7/7 - 0s - loss: 0.0282 - accuracy: 0.9850 - val_loss: 3.2666 - val_accuracy: 0.5500
# Epoch 47/500
# 7/7 - 0s - loss: 0.2017 - accuracy: 0.9600 - val_loss: 2.6499 - val_accuracy: 0.6000
# Epoch 48/500
# 7/7 - 1s - loss: 0.0764 - accuracy: 0.9650 - val_loss: 3.3115 - val_accuracy: 0.3500
# Epoch 1/500
# 7/7 - 2s - loss: 0.6325 - accuracy: 0.6600 - val_loss: 0.6044 - val_accuracy: 0.6500
# Epoch 2/500
# 7/7 - 0s - loss: 0.5562 - accuracy: 0.7550 - val_loss: 0.5933 - val_accuracy: 0.6500
# Epoch 3/500
# 7/7 - 0s - loss: 0.5217 - accuracy: 0.7550 - val_loss: 0.6063 - val_accuracy: 0.6500
# Epoch 4/500
# 7/7 - 0s - loss: 0.5179 - accuracy: 0.7550 - val_loss: 0.5853 - val_accuracy: 0.6500
# Epoch 5/500
# 7/7 - 0s - loss: 0.5322 - accuracy: 0.7550 - val_loss: 0.5865 - val_accuracy: 0.6500
# Epoch 6/500
# 7/7 - 0s - loss: 0.5184 - accuracy: 0.7550 - val_loss: 0.5997 - val_accuracy: 0.6500
# Epoch 7/500
# 7/7 - 0s - loss: 0.5152 - accuracy: 0.7550 - val_loss: 0.5791 - val_accuracy: 0.6500
# Epoch 8/500
# 7/7 - 0s - loss: 0.5142 - accuracy: 0.7550 - val_loss: 0.5787 - val_accuracy: 0.6500
# Epoch 9/500
# 7/7 - 1s - loss: 0.5270 - accuracy: 0.7550 - val_loss: 0.5778 - val_accuracy: 0.6500
# Epoch 10/500
# 7/7 - 0s - loss: 0.5107 - accuracy: 0.7550 - val_loss: 0.6115 - val_accuracy: 0.6500
# Epoch 11/500
# 7/7 - 1s - loss: 0.4972 - accuracy: 0.7600 - val_loss: 0.5571 - val_accuracy: 0.6500
# Epoch 12/500
# 7/7 - 0s - loss: 0.4827 - accuracy: 0.7650 - val_loss: 0.5990 - val_accuracy: 0.6500
# Epoch 13/500
# 7/7 - 1s - loss: 0.4843 - accuracy: 0.7800 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 14/500
# 7/7 - 0s - loss: 0.4543 - accuracy: 0.8150 - val_loss: 0.5994 - val_accuracy: 0.6750
# Epoch 15/500
# 7/7 - 1s - loss: 0.4742 - accuracy: 0.7900 - val_loss: 0.6143 - val_accuracy: 0.6750
# Epoch 16/500
# 7/7 - 1s - loss: 0.4607 - accuracy: 0.7900 - val_loss: 0.6249 - val_accuracy: 0.6250
# Epoch 17/500
# 7/7 - 1s - loss: 0.4165 - accuracy: 0.8250 - val_loss: 0.8153 - val_accuracy: 0.6500
# Epoch 18/500
# 7/7 - 0s - loss: 0.4605 - accuracy: 0.7800 - val_loss: 0.5966 - val_accuracy: 0.7000
# Epoch 19/500
# 7/7 - 0s - loss: 0.3989 - accuracy: 0.8300 - val_loss: 0.5945 - val_accuracy: 0.7250
# Epoch 20/500
# 7/7 - 0s - loss: 0.3523 - accuracy: 0.8500 - val_loss: 0.6420 - val_accuracy: 0.7250
# Epoch 21/500
# 7/7 - 0s - loss: 0.3152 - accuracy: 0.8900 - val_loss: 0.7735 - val_accuracy: 0.6250
# Epoch 22/500
# 7/7 - 0s - loss: 0.2635 - accuracy: 0.8950 - val_loss: 1.0815 - val_accuracy: 0.6500
# Epoch 23/500
# 7/7 - 0s - loss: 0.4746 - accuracy: 0.7850 - val_loss: 1.0922 - val_accuracy: 0.6500
# Epoch 24/500
# 7/7 - 0s - loss: 0.4182 - accuracy: 0.8400 - val_loss: 0.5538 - val_accuracy: 0.7250
# Epoch 25/500
# 7/7 - 0s - loss: 0.3910 - accuracy: 0.8450 - val_loss: 0.7297 - val_accuracy: 0.6500
# Epoch 26/500
# 7/7 - 0s - loss: 0.3051 - accuracy: 0.8650 - val_loss: 0.7301 - val_accuracy: 0.6250
# Epoch 27/500
# 7/7 - 0s - loss: 0.2407 - accuracy: 0.9050 - val_loss: 0.9477 - val_accuracy: 0.6500
# Epoch 28/500
# 7/7 - 0s - loss: 0.1507 - accuracy: 0.9450 - val_loss: 0.7474 - val_accuracy: 0.7000
# Epoch 29/500
# 7/7 - 0s - loss: 0.1581 - accuracy: 0.9350 - val_loss: 1.9582 - val_accuracy: 0.6500
# Epoch 30/500
# 7/7 - 0s - loss: 0.2312 - accuracy: 0.9200 - val_loss: 1.1224 - val_accuracy: 0.6500
# Epoch 31/500
# 7/7 - 0s - loss: 0.1160 - accuracy: 0.9600 - val_loss: 1.0323 - val_accuracy: 0.6750
# Epoch 32/500
# 7/7 - 0s - loss: 0.0848 - accuracy: 0.9700 - val_loss: 0.8508 - val_accuracy: 0.7500
# Epoch 33/500
# 7/7 - 1s - loss: 0.0496 - accuracy: 0.9900 - val_loss: 1.3950 - val_accuracy: 0.6750
# Epoch 34/500
# 7/7 - 0s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.6568 - val_accuracy: 0.6500
# Epoch 35/500
# 7/7 - 0s - loss: 0.0181 - accuracy: 0.9900 - val_loss: 1.2898 - val_accuracy: 0.7000
# Epoch 36/500
# 7/7 - 0s - loss: 0.0159 - accuracy: 0.9900 - val_loss: 1.4978 - val_accuracy: 0.6000
# Epoch 37/500
# 7/7 - 1s - loss: 0.2148 - accuracy: 0.9300 - val_loss: 3.4279 - val_accuracy: 0.4250
# Epoch 38/500
# 7/7 - 0s - loss: 0.7818 - accuracy: 0.8300 - val_loss: 1.1346 - val_accuracy: 0.6250
# Epoch 39/500
# 7/7 - 0s - loss: 0.2083 - accuracy: 0.9150 - val_loss: 0.6403 - val_accuracy: 0.7250
# Epoch 40/500
# 7/7 - 0s - loss: 0.2301 - accuracy: 0.9150 - val_loss: 0.8009 - val_accuracy: 0.6250
# Epoch 41/500
# 7/7 - 0s - loss: 0.1070 - accuracy: 0.9700 - val_loss: 0.6856 - val_accuracy: 0.7750
# Epoch 42/500
# 7/7 - 0s - loss: 0.0469 - accuracy: 0.9900 - val_loss: 1.3815 - val_accuracy: 0.6500
# Epoch 43/500
# 7/7 - 0s - loss: 0.0895 - accuracy: 0.9600 - val_loss: 1.1160 - val_accuracy: 0.6750
# Epoch 44/500
# 7/7 - 0s - loss: 0.0757 - accuracy: 0.9750 - val_loss: 1.4558 - val_accuracy: 0.7000
# Epoch 45/500
# 7/7 - 0s - loss: 0.0277 - accuracy: 0.9900 - val_loss: 1.1712 - val_accuracy: 0.6750
# Epoch 46/500
# 7/7 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.7215 - val_accuracy: 0.6500
# Epoch 47/500
# 7/7 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.6027 - val_accuracy: 0.6500
# Epoch 48/500
# 7/7 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.4577 - val_accuracy: 0.6500
# Epoch 49/500
# 7/7 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7737 - val_accuracy: 0.6750
# Epoch 1/500
# 7/7 - 2s - loss: 0.6393 - accuracy: 0.6350 - val_loss: 0.5979 - val_accuracy: 0.7250
# Epoch 2/500
# 7/7 - 0s - loss: 0.6012 - accuracy: 0.7050 - val_loss: 0.6146 - val_accuracy: 0.7250
# Epoch 3/500
# 7/7 - 0s - loss: 0.6002 - accuracy: 0.7050 - val_loss: 0.5838 - val_accuracy: 0.7250
# Epoch 4/500
# 7/7 - 0s - loss: 0.5609 - accuracy: 0.7050 - val_loss: 0.5775 - val_accuracy: 0.7250
# Epoch 5/500
# 7/7 - 0s - loss: 0.5639 - accuracy: 0.7050 - val_loss: 0.5826 - val_accuracy: 0.7250
# Epoch 6/500
# 7/7 - 0s - loss: 0.5336 - accuracy: 0.7200 - val_loss: 0.6059 - val_accuracy: 0.7250
# Epoch 7/500
# 7/7 - 0s - loss: 0.5564 - accuracy: 0.7350 - val_loss: 0.6339 - val_accuracy: 0.7250
# Epoch 8/500
# 7/7 - 0s - loss: 0.5627 - accuracy: 0.7700 - val_loss: 0.5939 - val_accuracy: 0.7250
# Epoch 9/500
# 7/7 - 0s - loss: 0.5299 - accuracy: 0.7550 - val_loss: 0.5859 - val_accuracy: 0.7250
# Epoch 10/500
# 7/7 - 0s - loss: 0.5167 - accuracy: 0.7850 - val_loss: 0.6061 - val_accuracy: 0.7250
# Epoch 11/500
# 7/7 - 0s - loss: 0.5242 - accuracy: 0.7800 - val_loss: 0.6044 - val_accuracy: 0.7250
# Epoch 12/500
# 7/7 - 0s - loss: 0.5357 - accuracy: 0.7350 - val_loss: 0.5752 - val_accuracy: 0.7500
# Epoch 13/500
# 7/7 - 0s - loss: 0.5111 - accuracy: 0.7700 - val_loss: 0.6226 - val_accuracy: 0.7250
# Epoch 14/500
# 7/7 - 0s - loss: 0.4945 - accuracy: 0.7900 - val_loss: 0.6217 - val_accuracy: 0.7250
# Epoch 15/500
# 7/7 - 0s - loss: 0.5047 - accuracy: 0.7750 - val_loss: 0.6847 - val_accuracy: 0.6750
# Epoch 16/500
# 7/7 - 0s - loss: 0.4720 - accuracy: 0.7950 - val_loss: 0.6184 - val_accuracy: 0.7250
# Epoch 17/500
# 7/7 - 0s - loss: 0.5029 - accuracy: 0.7750 - val_loss: 0.6338 - val_accuracy: 0.7250
# Epoch 18/500
# 7/7 - 0s - loss: 0.4715 - accuracy: 0.7950 - val_loss: 0.6435 - val_accuracy: 0.7250
# Epoch 19/500
# 7/7 - 0s - loss: 0.4491 - accuracy: 0.8100 - val_loss: 0.7244 - val_accuracy: 0.6250
# Epoch 20/500
# 7/7 - 0s - loss: 0.3986 - accuracy: 0.8350 - val_loss: 0.6776 - val_accuracy: 0.7250
# Epoch 21/500
# 7/7 - 0s - loss: 0.3709 - accuracy: 0.8550 - val_loss: 0.8280 - val_accuracy: 0.6500
# Epoch 22/500
# 7/7 - 0s - loss: 0.3121 - accuracy: 0.8900 - val_loss: 0.8048 - val_accuracy: 0.7250
# Epoch 23/500
# 7/7 - 0s - loss: 0.2497 - accuracy: 0.9200 - val_loss: 0.8956 - val_accuracy: 0.6500
# Epoch 24/500
# 7/7 - 0s - loss: 0.3977 - accuracy: 0.8300 - val_loss: 0.9172 - val_accuracy: 0.7000
# Epoch 25/500
# 7/7 - 0s - loss: 0.4377 - accuracy: 0.8200 - val_loss: 0.7826 - val_accuracy: 0.7250
# Epoch 26/500
# 7/7 - 0s - loss: 0.3192 - accuracy: 0.8750 - val_loss: 0.8783 - val_accuracy: 0.6000
# Epoch 27/500
# 7/7 - 0s - loss: 0.2411 - accuracy: 0.9200 - val_loss: 1.0091 - val_accuracy: 0.6000
# Epoch 28/500
# 7/7 - 0s - loss: 0.2092 - accuracy: 0.9250 - val_loss: 1.0415 - val_accuracy: 0.6250
# Epoch 29/500
# 7/7 - 0s - loss: 0.1426 - accuracy: 0.9500 - val_loss: 1.1134 - val_accuracy: 0.6500
# Epoch 30/500
# 7/7 - 0s - loss: 0.2089 - accuracy: 0.9150 - val_loss: 1.2449 - val_accuracy: 0.6500
# Epoch 31/500
# 7/7 - 0s - loss: 0.2896 - accuracy: 0.8950 - val_loss: 1.1278 - val_accuracy: 0.7000
# Epoch 32/500
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8600 - val_loss: 0.8170 - val_accuracy: 0.6750
# Epoch 33/500
# 7/7 - 0s - loss: 0.2623 - accuracy: 0.8900 - val_loss: 1.1863 - val_accuracy: 0.5500
# Epoch 34/500
# 7/7 - 0s - loss: 0.1850 - accuracy: 0.9400 - val_loss: 1.1048 - val_accuracy: 0.6750
# Epoch 35/500
# 7/7 - 0s - loss: 0.1415 - accuracy: 0.9550 - val_loss: 1.4218 - val_accuracy: 0.5500
# Epoch 36/500
# 7/7 - 0s - loss: 0.1197 - accuracy: 0.9450 - val_loss: 1.6940 - val_accuracy: 0.5250
# Epoch 37/500
# 7/7 - 1s - loss: 0.1055 - accuracy: 0.9600 - val_loss: 1.7026 - val_accuracy: 0.5250
# Epoch 1/500
# 7/7 - 1s - loss: 0.6284 - accuracy: 0.7150 - val_loss: 0.4994 - val_accuracy: 0.7750
# Epoch 2/500
# 7/7 - 1s - loss: 0.5803 - accuracy: 0.7150 - val_loss: 0.4989 - val_accuracy: 0.7750
# Epoch 3/500
# 7/7 - 0s - loss: 0.5931 - accuracy: 0.7150 - val_loss: 0.5263 - val_accuracy: 0.7750
# Epoch 4/500
# 7/7 - 1s - loss: 0.5903 - accuracy: 0.7150 - val_loss: 0.5489 - val_accuracy: 0.7750
# Epoch 5/500
# 7/7 - 1s - loss: 0.5738 - accuracy: 0.7150 - val_loss: 0.4954 - val_accuracy: 0.7750
# Epoch 6/500
# 7/7 - 0s - loss: 0.5634 - accuracy: 0.7150 - val_loss: 0.4930 - val_accuracy: 0.7750
# Epoch 7/500
# 7/7 - 0s - loss: 0.5547 - accuracy: 0.7150 - val_loss: 0.4910 - val_accuracy: 0.7750
# Epoch 8/500
# 7/7 - 0s - loss: 0.5509 - accuracy: 0.7150 - val_loss: 0.4957 - val_accuracy: 0.7750
# Epoch 9/500
# 7/7 - 0s - loss: 0.5502 - accuracy: 0.7150 - val_loss: 0.5238 - val_accuracy: 0.7500
# Epoch 10/500
# 7/7 - 0s - loss: 0.5749 - accuracy: 0.7500 - val_loss: 0.5035 - val_accuracy: 0.7250
# Epoch 11/500
# 7/7 - 0s - loss: 0.5423 - accuracy: 0.7150 - val_loss: 0.4952 - val_accuracy: 0.7250
# Epoch 12/500
# 7/7 - 0s - loss: 0.5346 - accuracy: 0.7600 - val_loss: 0.5425 - val_accuracy: 0.7500
# Epoch 13/500
# 7/7 - 0s - loss: 0.5654 - accuracy: 0.7650 - val_loss: 0.5061 - val_accuracy: 0.7500
# Epoch 14/500
# 7/7 - 0s - loss: 0.5205 - accuracy: 0.7450 - val_loss: 0.5192 - val_accuracy: 0.7250
# Epoch 15/500
# 7/7 - 0s - loss: 0.5080 - accuracy: 0.7600 - val_loss: 0.5080 - val_accuracy: 0.7500
# Epoch 16/500
# 7/7 - 0s - loss: 0.4686 - accuracy: 0.7950 - val_loss: 0.5233 - val_accuracy: 0.7750
# Epoch 17/500
# 7/7 - 0s - loss: 0.4439 - accuracy: 0.7800 - val_loss: 0.5885 - val_accuracy: 0.7500
# Epoch 18/500
# 7/7 - 0s - loss: 0.3453 - accuracy: 0.8550 - val_loss: 0.6316 - val_accuracy: 0.7500
# Epoch 19/500
# 7/7 - 0s - loss: 0.3183 - accuracy: 0.8600 - val_loss: 0.8869 - val_accuracy: 0.4500
# Epoch 20/500
# 7/7 - 0s - loss: 0.4205 - accuracy: 0.8200 - val_loss: 0.8927 - val_accuracy: 0.5000
# Epoch 21/500
# 7/7 - 0s - loss: 0.3820 - accuracy: 0.8600 - val_loss: 0.7866 - val_accuracy: 0.5500
# Epoch 22/500
# 7/7 - 1s - loss: 0.3223 - accuracy: 0.8800 - val_loss: 0.8056 - val_accuracy: 0.7500
# Epoch 23/500
# 7/7 - 0s - loss: 0.2805 - accuracy: 0.8900 - val_loss: 0.6499 - val_accuracy: 0.7750
# Epoch 24/500
# 7/7 - 0s - loss: 0.2991 - accuracy: 0.8700 - val_loss: 0.7208 - val_accuracy: 0.6750
# Epoch 25/500
# 7/7 - 1s - loss: 0.2201 - accuracy: 0.9100 - val_loss: 0.7978 - val_accuracy: 0.7000
# Epoch 26/500
# 7/7 - 1s - loss: 0.1413 - accuracy: 0.9550 - val_loss: 1.1052 - val_accuracy: 0.6500
# Epoch 27/500
# 7/7 - 1s - loss: 0.0742 - accuracy: 0.9800 - val_loss: 1.4053 - val_accuracy: 0.6500
# Epoch 28/500
# 7/7 - 0s - loss: 0.0398 - accuracy: 0.9750 - val_loss: 1.7776 - val_accuracy: 0.7250
# Epoch 29/500
# 7/7 - 0s - loss: 0.0701 - accuracy: 0.9650 - val_loss: 1.6735 - val_accuracy: 0.6750
# Epoch 30/500
# 7/7 - 1s - loss: 0.1699 - accuracy: 0.9300 - val_loss: 1.3661 - val_accuracy: 0.7250
# Epoch 31/500
# 7/7 - 1s - loss: 0.2066 - accuracy: 0.9450 - val_loss: 1.4782 - val_accuracy: 0.5250
# Epoch 32/500
# 7/7 - 1s - loss: 0.1668 - accuracy: 0.9150 - val_loss: 0.8210 - val_accuracy: 0.7000
# Epoch 1/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 2/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 3/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 4/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 5/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 6/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 7/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 8/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 9/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 10/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 11/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 12/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 13/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 14/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 15/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 16/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 17/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 18/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 19/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 20/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 21/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 22/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 23/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 24/500
# 7/7 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 25/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500
# Epoch 26/500
# 7/7 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.3500

# %%
#Testing which model I'll pick

# %%
with open('../partition_train_val_a.dat', 'rb') as f:
    partition = pickle.load(f)
train_samples_IDs = partition['train']
val_samples_IDs = partition['validation']
IDs = partition['labels']

# %%
model = load_model('../Models_H5/011_{}-conv-{}-nodes-{}-dense-{}CNNLSTM'.format(1, 128, 1, 1601188309))

# %%
predicted = []
Y_val_expected = []
count_input_val = 0
num_val_seq = len(partition['validation'])
done = False
while count_input_val < num_val_seq and not(done):
    X_val = np.zeros((200, 1000, 4), dtype=np.int8)
    if count_input_val < (num_val_seq - 200):
        for i in range(0, 200):
            a = partition['validation'][count_input_val]
            X_val[i, :, :] = np.load('../model_11_data_4/' + partition['validation'][count_input_val] + '.npy') 
            count_input_val += 1
        predict = (model.predict_classes(X_val))
        for label in predict:
            predicted.append(label)
    else:
        done = True
    if count_input_val == 16200:
        done = True
    print(count_input_val)
print(len(predicted))
print(predicted[0])
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13400
# 13400
# 1

# %%
expected = []

for label in val_samples_IDs:
    expected.append(IDs[label][0][0])
print(expected[0])
print(len(expected))
# Out:
# 1
# 13520

# %%
# Example of a confusion matrix in Python
from sklearn.metrics import confusion_matrix
 
results = confusion_matrix(expected[0:13400], predicted)
print(results)
# Printing the precision and recall, among other metrics
#print(metrics.classification_report(y_act, y_pred, labels=["a", 
#"b"]))
# Out:
# [[   0 7199]
#  [   0 6201]]

# %%
import seaborn as sns

sns.heatmap(results/np.sum(results), annot=True, 
            fmt='.2%', cmap='Blues')
print(model.summary)
# Out:
# <bound method Model.summary of <tensorflow.python.keras.engine.sequential.Sequential object at 0x00000280A20A8F10>>

# %%
### HERE 1

# %% [markdown]
# Extra Code:

# %%
with open('../partition_test_a.dat', 'rb') as f:
    partition = pickle.load(f)
test_samples_IDs = partition['test']

with open('../test_labels.dat', 'rb') as f:
    test_labels = pickle.load(f)
print(len(test_labels))
# Out:
# 16382

# %%
model = load_model('../Models_H5/SURF_Paper_9.26.20/011_{}-conv-{}-nodes-{}-dense-{}CNNLSTM-9-26-20'.format(1, 64, 0, 1601093561))

# %%
predicted = []
count_input_test = 0
num_test_seq = len(partition['test'])
done = False
while count_input_test < num_test_seq and not(done):
    X_test = np.zeros((200, 1000, 4), dtype=np.int8)
    if count_input_test < (num_test_seq - 200):
        for i in range(0, 200):
            a = partition['test'][count_input_test]
            X_test[i, :, :] = np.load('../DataSet_14_Test_2/' + partition['test'][count_input_test] + '.npy') 
            count_input_test += 1
        predict = (model.predict_classes(X_test))
        for label in predict:
            predicted.append(label)
    else:
        done = True
    if count_input_test == 16200:
        done = True
    print(count_input_test)
print(len(predicted))
print(len(test_labels))
print(predicted[0])
# Out:
# WARNING:tensorflow:From <ipython-input-6-a111254a8890>:12: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13600
# 13800
# 14000
# 14200
# 14400
# 14600
# 14800
# 15000
# 15200
# 15400
# 15600
# 15800
# 16000
# 16200
# 16200
# 16382
# 1

# %%
expected = []
for label in test_labels[0:16200]:
    expected.append(label[0][0])
print(expected[0])
# Out:
# 1

# %%
# Example of a confusion matrix in Python
from sklearn.metrics import confusion_matrix
 
results = confusion_matrix(expected, predicted)
print(results)
# Printing the precision and recall, among other metrics
#print(metrics.classification_report(y_act, y_pred, labels=["a", 
#"b"]))
# Out:
# [[   0 8568]
#  [   0 7632]]

# %%
sns.heatmap(results/np.sum(results), annot=True, 
            fmt='.2%', cmap='Blues')
print(model.summary())
# Out:
# ------------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-9-6ad8cf9d9a02> in <module>
# ----> 1 sns.heatmap(results/np.sum(results), annot=True,
#       2             fmt='.2%', cmap='Blues')
#       3 print(model.summary())
#
# NameError: name 'sns' is not defined

# %%
import tensorflow as tf
print(tf.__version__)

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss')<0.4):
      print("\nReached 60% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images/255.0
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.fit(training_images, training_labels, epochs=5, callbacks=[callbacks])
